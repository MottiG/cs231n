# %% [markdown]
# # Fully-Connected Neural Nets
# In the previous homework you implemented a fully-connected two-layer neural network on CIFAR-10. The implementation was simple but not very modular since the loss and gradient were computed in a single monolithic function. This is manageable for a simple two-layer network, but would become impractical as we move to bigger models. Ideally we want to build networks using a more modular design so that we can implement different layer types in isolation and then snap them together into models with different architectures.
#
# In this exercise we will implement fully-connected networks using a more modular approach. For each layer we will implement a `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive derivative of loss with respect to outputs and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.
#
# In addition to implementing fully-connected networks of arbitrary depth, we will also explore different update rules for optimization, and introduce Dropout as a regularizer and Batch Normalization as a tool to more efficiently optimize deep networks.

# %%
# As usual, a bit of setup
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (14.0, 12.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k, v in list(data.items()):
  print(('%s: ' % k, v.shape))
# Out:
# ('X_train: ', (49000, 3, 32, 32))
# ('y_train: ', (49000,))
# ('X_val: ', (1000, 3, 32, 32))
# ('y_val: ', (1000,))
# ('X_test: ', (1000, 3, 32, 32))
# ('y_test: ', (1000,))

# %% [markdown]
# # Affine layer: foward
# Open the file `cs231n/layers.py` and implement the `affine_forward` function.
#
# Once you are done you can test your implementaion by running the following:

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])

# Compare your output with ours. The error should be around 1e-9.
print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))

# %% [markdown]
# # Affine layer: backward
# Now implement the `affine_backward` function and test your implementation using numeric gradient checking.

# %%
# Test the affine_backward function
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around 1e-10
print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))

# %% [markdown]
# # ReLU layer: forward
# Implement the forward pass for the ReLU activation function in the `relu_forward` function and test your implementation using the following:

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be around 5e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))

# %% [markdown]
# # ReLU layer: backward
# Now implement the backward pass for the ReLU activation function in the `relu_backward` function and test your implementation using numeric gradient checking:

# %%
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)
_, cache = relu_forward(x)
dx = relu_backward(dout, cache)
# The error should be around 3e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))

# %% [markdown]
# # "Sandwich" layers
# There are some common patterns of layers that are frequently used in neural nets. For example, affine layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, we define several convenience layers in the file `cs231n/layer_utils.py`.
#
# For now take a look at the `affine_relu_forward` and `affine_relu_backward` functions, and run the following to numerically gradient check the backward pass:

# %%
from cs231n.layer_utils import affine_relu_forward, affine_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

print('Testing affine_relu_forward:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))

# %% [markdown]
# # Loss layers: Softmax and SVM
# You implemented these loss functions in the last assignment, so we'll give them to you for free here. You should still make sure you understand how they work by looking at the implementations in `cs231n/layers.py`.
#
# You can make sure that the implementations are correct by running the following:

# %%
np.random.seed(231)
num_classes, num_inputs = 10, 50
x = 0.001 * np.random.randn(num_inputs, num_classes)
y = np.random.randint(num_classes, size=num_inputs)

dx_num = eval_numerical_gradient(lambda x: svm_loss(x, y)[0], x, verbose=False)
loss, dx = svm_loss(x, y)

# Test svm_loss function. Loss should be around 9 and dx error should be 1e-9
print('Testing svm_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))

dx_num = eval_numerical_gradient(lambda x: softmax_loss(x, y)[0], x, verbose=False)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be 2.3 and dx error should be 1e-8
print('\nTesting softmax_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))

# %% [markdown]
# # Two-layer network
# In the previous assignment you implemented a two-layer neural network in a single monolithic class. Now that you have implemented modular versions of the necessary layers, you will reimplement the two layer network using these modular implementations.
#
# Open the file `cs231n/classifiers/fc_net.py` and complete the implementation of the `TwoLayerNet` class. This class will serve as a model for the other networks you will implement in this assignment, so read through it to make sure you understand the API. You can run the cell below to test your implementation.

# %%
np.random.seed(231)
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-3
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))

# %% [markdown]
# # Solver
# In the previous assignment, the logic for training models was coupled to the models themselves. Following a more modular design, for this assignment we have split the logic for training models into a separate class.
#
# Open the file `cs231n/solver.py` and read through it to familiarize yourself with the API. After doing so, use a `Solver` instance to train a `TwoLayerNet` that achieves at least `50%` accuracy on the validation set.

# %%
model = TwoLayerNet(reg = 1.5)
solver = None

##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves at least  #
# 50% accuracy on the validation set.                                        #
##############################################################################
optim_config = {'learning_rate': 1e-3}
lr_decay=0.95
solver = Solver(model=model, data=data, optim_config=optim_config, lr_decay=lr_decay)
solver.train()
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################

# %%
# Run this cell to visualize training loss and train / val accuracy

plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# # Multilayer network
# Next you will implement a fully-connected network with an arbitrary number of hidden layers.
#
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the initialization, the forward pass, and the backward pass. For the moment don't worry about implementing dropout or batch normalization; we will add those features soon.

# %% [markdown]
# ## Initial loss and gradient check

# %% [markdown]
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. Do the initial losses seem reasonable?
#
# For gradient checking, you should expect to see errors around 1e-6 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))

# %% [markdown]
# As another sanity check, make sure you can overfit a small dataset of 50 images. First we will try a three-layer network with 100 units in each hidden layer. You will need to tweak the learning rate and initialization scale, but you should be able to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 1e-1
learning_rate = 1e-3
model = FullyConnectedNet([100, 100],
              weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()

# %% [markdown]
# Now try to use a five-layer network with 100 units on each layer to overfit 50 training examples. Again you will have to adjust the learning rate and weight initialization, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate = 1e-3
weight_scale = 1e-1
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()

# %% [markdown]
# # Inline question:
# Did you notice anything about the comparative difficulty of training the three-layer net vs training the five layer net?
#
# # Answer:
# When we have more weights with more layers, the tweaking process is harder

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# # SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochstic gradient descent.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than 1e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

print('next_w error: ', rel_error(next_w, expected_next_w))
print('velocity error: ', rel_error(expected_velocity, config['velocity']))

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': 1e-2,
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in list(solvers.items()):
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label=update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label=update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# # RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation; you should see errors less than 1e-7
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))

# %%
# Test Adam implementation; you should see errors around 1e-7 or less
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': learning_rates[update_rule]
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in list(solvers.items()):
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label=update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label=update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# # Train a good model!
# Train the best fully-connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully-connected net.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the assignment we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional nets rather than fully-connected nets.
#
# You might find it useful to complete the `BatchNormalization.ipynb` and `Dropout.ipynb` notebooks before completing this part, since those techniques can help you train powerful models.

# %%
best_model = None
best_val = -1
################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# batch normalization and dropout useful. Store your best model in the         #
# best_model variable.                                                         #
################################################################################

# model params
reg = 0.0
nums_hidden_dims = [5, 7, 10, 15]
ps = [0, 0.25, 0.5, 0.75]

# solver params
lrs = [1e-1,3e-1,1e-3,3e-3,1e-5,3e-5]
conf = {'update_rule': 'adam', 'lr_decay': 0.95, 'num_epochs':10, 'batch_size': 128, 'print_every': 100}

for p in ps:
    for num_hiddens in nums_hidden_dims:
        for lr in lrs:
            
            print('lr: {}, num_hiddens: {}, p: {}'.format(lr, num_hiddens, p))
            
            conf['optim_config'] = {'learning_rate': lr}
            model = FullyConnectedNet(hidden_dims=[100]*num_hiddens, 
                                      dropout=p, 
                                      use_batchnorm=True, 
                                      reg=reg, 
                                      dtype=np.float64)
            solver = Solver(model, data, **conf)
            solver.train()
            curr_val = max(solver.val_acc_history)
            if curr_val > best_val:
                best_val = curr_val
                best_model = model
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# lr: 0.1, num_hiddens: 5, p: 0
# (Iteration 1 / 3820) loss: 2.302115
# (Epoch 0 / 10) train acc: 0.119000; val_acc: 0.107000
# (Iteration 101 / 3820) loss: 1.926850
# (Iteration 201 / 3820) loss: 1.885124
# (Iteration 301 / 3820) loss: 1.626001
# (Epoch 1 / 10) train acc: 0.356000; val_acc: 0.344000
# (Iteration 401 / 3820) loss: 1.811685
# (Iteration 501 / 3820) loss: 1.711120
# (Iteration 601 / 3820) loss: 1.693495
# (Iteration 701 / 3820) loss: 1.612820
# (Epoch 2 / 10) train acc: 0.438000; val_acc: 0.435000
# (Iteration 801 / 3820) loss: 1.705370
# (Iteration 901 / 3820) loss: 1.460544
# (Iteration 1001 / 3820) loss: 1.747175
# (Iteration 1101 / 3820) loss: 1.728699
# (Epoch 3 / 10) train acc: 0.433000; val_acc: 0.442000
# (Iteration 1201 / 3820) loss: 1.393564
# (Iteration 1301 / 3820) loss: 1.508438
# (Iteration 1401 / 3820) loss: 1.409075
# (Iteration 1501 / 3820) loss: 1.533359
# (Epoch 4 / 10) train acc: 0.449000; val_acc: 0.471000
# (Iteration 1601 / 3820) loss: 1.442224
# (Iteration 1701 / 3820) loss: 1.445371
# (Iteration 1801 / 3820) loss: 1.482650
# (Iteration 1901 / 3820) loss: 1.409496
# (Epoch 5 / 10) train acc: 0.484000; val_acc: 0.480000
# (Iteration 2001 / 3820) loss: 1.502789
# (Iteration 2101 / 3820) loss: 1.278089
# (Iteration 2201 / 3820) loss: 1.417470
# (Epoch 6 / 10) train acc: 0.525000; val_acc: 0.497000
# (Iteration 2301 / 3820) loss: 1.516184
# (Iteration 2401 / 3820) loss: 1.315853
# (Iteration 2501 / 3820) loss: 1.384510
# (Iteration 2601 / 3820) loss: 1.343142
# (Epoch 7 / 10) train acc: 0.561000; val_acc: 0.496000
# (Iteration 2701 / 3820) loss: 1.349150
# (Iteration 2801 / 3820) loss: 1.489955
# (Iteration 2901 / 3820) loss: 1.514516
# (Iteration 3001 / 3820) loss: 1.263372
# (Epoch 8 / 10) train acc: 0.567000; val_acc: 0.496000
# (Iteration 3101 / 3820) loss: 1.272133
# (Iteration 3201 / 3820) loss: 1.283155
# (Iteration 3301 / 3820) loss: 1.297701
# (Iteration 3401 / 3820) loss: 1.312743
# (Epoch 9 / 10) train acc: 0.558000; val_acc: 0.496000
# (Iteration 3501 / 3820) loss: 1.138515
# (Iteration 3601 / 3820) loss: 1.280827
# (Iteration 3701 / 3820) loss: 1.135007
# (Iteration 3801 / 3820) loss: 1.230769
# (Epoch 10 / 10) train acc: 0.562000; val_acc: 0.478000
# lr: 0.3, num_hiddens: 5, p: 0
# (Iteration 1 / 3820) loss: 2.306575
# (Epoch 0 / 10) train acc: 0.109000; val_acc: 0.119000
# (Iteration 101 / 3820) loss: 2.215691
# (Iteration 201 / 3820) loss: 2.121361
# (Iteration 301 / 3820) loss: 1.973699
# (Epoch 1 / 10) train acc: 0.189000; val_acc: 0.188000
# (Iteration 401 / 3820) loss: 1.971265
# (Iteration 501 / 3820) loss: 1.967465
# (Iteration 601 / 3820) loss: 2.010098
# (Iteration 701 / 3820) loss: 1.791142
# (Epoch 2 / 10) train acc: 0.264000; val_acc: 0.271000
# (Iteration 801 / 3820) loss: 1.814001
# (Iteration 901 / 3820) loss: 1.933792
# (Iteration 1001 / 3820) loss: 1.910253
# (Iteration 1101 / 3820) loss: 1.955618
# (Epoch 3 / 10) train acc: 0.286000; val_acc: 0.312000
# (Iteration 1201 / 3820) loss: 1.978587
# (Iteration 1301 / 3820) loss: 1.818718
# (Iteration 1401 / 3820) loss: 1.713003
# (Iteration 1501 / 3820) loss: 1.684706
# (Epoch 4 / 10) train acc: 0.332000; val_acc: 0.269000
# (Iteration 1601 / 3820) loss: 1.793208
# (Iteration 1701 / 3820) loss: 1.853530
# (Iteration 1801 / 3820) loss: 1.677837
# (Iteration 1901 / 3820) loss: 1.688381
# (Epoch 5 / 10) train acc: 0.288000; val_acc: 0.324000
# (Iteration 2001 / 3820) loss: 1.696153
# (Iteration 2101 / 3820) loss: 1.551818
# (Iteration 2201 / 3820) loss: 1.895445
# (Epoch 6 / 10) train acc: 0.344000; val_acc: 0.340000
# (Iteration 2301 / 3820) loss: 1.562187
# (Iteration 2401 / 3820) loss: 1.804859
# (Iteration 2501 / 3820) loss: 1.727724
# (Iteration 2601 / 3820) loss: 1.799904
# (Epoch 7 / 10) train acc: 0.366000; val_acc: 0.366000
# (Iteration 2701 / 3820) loss: 1.637274
# (Iteration 2801 / 3820) loss: 1.671437
# (Iteration 2901 / 3820) loss: 1.748331
# (Iteration 3001 / 3820) loss: 1.733999
# (Epoch 8 / 10) train acc: 0.359000; val_acc: 0.382000
# (Iteration 3101 / 3820) loss: 1.661073
# (Iteration 3201 / 3820) loss: 1.667473
# (Iteration 3301 / 3820) loss: 1.591537
# (Iteration 3401 / 3820) loss: 1.638306
# (Epoch 9 / 10) train acc: 0.383000; val_acc: 0.350000
# (Iteration 3501 / 3820) loss: 1.600588
# (Iteration 3601 / 3820) loss: 1.675871
# (Iteration 3701 / 3820) loss: 1.625132
# (Iteration 3801 / 3820) loss: 1.521917
# (Epoch 10 / 10) train acc: 0.377000; val_acc: 0.367000
# lr: 0.001, num_hiddens: 5, p: 0
# (Iteration 1 / 3820) loss: 2.299421
# (Epoch 0 / 10) train acc: 0.112000; val_acc: 0.082000
# (Iteration 101 / 3820) loss: 1.765584
# (Iteration 201 / 3820) loss: 1.556591
# (Iteration 301 / 3820) loss: 1.588720
# (Epoch 1 / 10) train acc: 0.484000; val_acc: 0.453000
# (Iteration 401 / 3820) loss: 1.497460
# (Iteration 501 / 3820) loss: 1.379226
# (Iteration 601 / 3820) loss: 1.364475
# (Iteration 701 / 3820) loss: 1.324245
# (Epoch 2 / 10) train acc: 0.512000; val_acc: 0.484000
# (Iteration 801 / 3820) loss: 1.334670
# (Iteration 901 / 3820) loss: 1.286925
# (Iteration 1001 / 3820) loss: 1.259581
# (Iteration 1101 / 3820) loss: 1.319777
# (Epoch 3 / 10) train acc: 0.539000; val_acc: 0.517000
# (Iteration 1201 / 3820) loss: 1.411492
# (Iteration 1301 / 3820) loss: 1.463931
# (Iteration 1401 / 3820) loss: 1.125066
# (Iteration 1501 / 3820) loss: 1.182336
# (Epoch 4 / 10) train acc: 0.584000; val_acc: 0.537000
# (Iteration 1601 / 3820) loss: 1.328351
# (Iteration 1701 / 3820) loss: 1.407921
# (Iteration 1801 / 3820) loss: 1.146856
# (Iteration 1901 / 3820) loss: 1.076630
# (Epoch 5 / 10) train acc: 0.606000; val_acc: 0.525000
# (Iteration 2001 / 3820) loss: 1.094894
# (Iteration 2101 / 3820) loss: 1.150408
# (Iteration 2201 / 3820) loss: 1.224893
# (Epoch 6 / 10) train acc: 0.597000; val_acc: 0.529000
# (Iteration 2301 / 3820) loss: 1.177206
# (Iteration 2401 / 3820) loss: 1.147409
# (Iteration 2501 / 3820) loss: 1.046862
# (Iteration 2601 / 3820) loss: 1.057716
# (Epoch 7 / 10) train acc: 0.596000; val_acc: 0.537000
# (Iteration 2701 / 3820) loss: 1.142967
# (Iteration 2801 / 3820) loss: 1.090625
# (Iteration 2901 / 3820) loss: 1.045087
# (Iteration 3001 / 3820) loss: 0.939749
# (Epoch 8 / 10) train acc: 0.642000; val_acc: 0.558000
# (Iteration 3101 / 3820) loss: 1.056992
# (Iteration 3201 / 3820) loss: 0.981336
# (Iteration 3301 / 3820) loss: 1.088161
# (Iteration 3401 / 3820) loss: 0.844715
# (Epoch 9 / 10) train acc: 0.674000; val_acc: 0.537000
# (Iteration 3501 / 3820) loss: 1.005357
# (Iteration 3601 / 3820) loss: 1.025464
# (Iteration 3701 / 3820) loss: 0.980501
# (Iteration 3801 / 3820) loss: 0.911278
# (Epoch 10 / 10) train acc: 0.670000; val_acc: 0.539000
# lr: 0.003, num_hiddens: 5, p: 0
# (Iteration 1 / 3820) loss: 2.299883
# (Epoch 0 / 10) train acc: 0.107000; val_acc: 0.133000
# (Iteration 101 / 3820) loss: 1.650061
# (Iteration 201 / 3820) loss: 1.646336
# (Iteration 301 / 3820) loss: 1.442809
# (Epoch 1 / 10) train acc: 0.462000; val_acc: 0.455000
# (Iteration 401 / 3820) loss: 1.599585
# (Iteration 501 / 3820) loss: 1.426551
# (Iteration 601 / 3820) loss: 1.338223
# (Iteration 701 / 3820) loss: 1.318278
# (Epoch 2 / 10) train acc: 0.489000; val_acc: 0.479000
# (Iteration 801 / 3820) loss: 1.371327
# (Iteration 901 / 3820) loss: 1.239193
# (Iteration 1001 / 3820) loss: 1.215036
# (Iteration 1101 / 3820) loss: 1.361884
# (Epoch 3 / 10) train acc: 0.535000; val_acc: 0.508000
# (Iteration 1201 / 3820) loss: 1.218901
# (Iteration 1301 / 3820) loss: 1.378220
# (Iteration 1401 / 3820) loss: 1.302427
# (Iteration 1501 / 3820) loss: 1.262491
# (Epoch 4 / 10) train acc: 0.568000; val_acc: 0.527000
# (Iteration 1601 / 3820) loss: 1.059571
# (Iteration 1701 / 3820) loss: 1.248872
# (Iteration 1801 / 3820) loss: 1.111133
# (Iteration 1901 / 3820) loss: 1.115586
# (Epoch 5 / 10) train acc: 0.574000; val_acc: 0.522000
# (Iteration 2001 / 3820) loss: 1.309943
# (Iteration 2101 / 3820) loss: 1.134841
# (Iteration 2201 / 3820) loss: 1.112350
# (Epoch 6 / 10) train acc: 0.611000; val_acc: 0.536000
# (Iteration 2301 / 3820) loss: 1.212570
# (Iteration 2401 / 3820) loss: 0.969334
# (Iteration 2501 / 3820) loss: 1.129617
# (Iteration 2601 / 3820) loss: 1.241293
# (Epoch 7 / 10) train acc: 0.628000; val_acc: 0.524000
# (Iteration 2701 / 3820) loss: 1.053694
# (Iteration 2801 / 3820) loss: 1.013419
# (Iteration 2901 / 3820) loss: 1.020990
# (Iteration 3001 / 3820) loss: 0.861103
# (Epoch 8 / 10) train acc: 0.674000; val_acc: 0.531000
# (Iteration 3101 / 3820) loss: 1.091465
# (Iteration 3201 / 3820) loss: 1.118668
# (Iteration 3301 / 3820) loss: 0.952946
# (Iteration 3401 / 3820) loss: 0.895068
# (Epoch 9 / 10) train acc: 0.668000; val_acc: 0.532000
# (Iteration 3501 / 3820) loss: 0.860254
# (Iteration 3601 / 3820) loss: 0.818068
# (Iteration 3701 / 3820) loss: 0.916797
# (Iteration 3801 / 3820) loss: 0.858839
# (Epoch 10 / 10) train acc: 0.654000; val_acc: 0.555000
# lr: 1e-05, num_hiddens: 5, p: 0
# (Iteration 1 / 3820) loss: 2.299104
# (Epoch 0 / 10) train acc: 0.095000; val_acc: 0.112000
# (Iteration 101 / 3820) loss: 2.249667
# (Iteration 201 / 3820) loss: 2.242963
# (Iteration 301 / 3820) loss: 2.152245
# (Epoch 1 / 10) train acc: 0.317000; val_acc: 0.314000
# (Iteration 401 / 3820) loss: 2.106839
# (Iteration 501 / 3820) loss: 2.099924
# (Iteration 601 / 3820) loss: 2.044648
# (Iteration 701 / 3820) loss: 2.055718
# (Epoch 2 / 10) train acc: 0.380000; val_acc: 0.368000
# (Iteration 801 / 3820) loss: 1.979854
# (Iteration 901 / 3820) loss: 1.991866
# (Iteration 1001 / 3820) loss: 1.986038
# (Iteration 1101 / 3820) loss: 1.945713
# (Epoch 3 / 10) train acc: 0.376000; val_acc: 0.391000
# (Iteration 1201 / 3820) loss: 1.875732
# (Iteration 1301 / 3820) loss: 1.941310
# (Iteration 1401 / 3820) loss: 1.874359
# (Iteration 1501 / 3820) loss: 1.798668
# (Epoch 4 / 10) train acc: 0.444000; val_acc: 0.411000
# (Iteration 1601 / 3820) loss: 1.841757
# (Iteration 1701 / 3820) loss: 1.848897
# (Iteration 1801 / 3820) loss: 1.739289
# (Iteration 1901 / 3820) loss: 1.744325
# (Epoch 5 / 10) train acc: 0.482000; val_acc: 0.415000
# (Iteration 2001 / 3820) loss: 1.794804
# (Iteration 2101 / 3820) loss: 1.803069
# (Iteration 2201 / 3820) loss: 1.680016
# (Epoch 6 / 10) train acc: 0.451000; val_acc: 0.436000
# (Iteration 2301 / 3820) loss: 1.813522
# (Iteration 2401 / 3820) loss: 1.786948
# (Iteration 2501 / 3820) loss: 1.726643
# (Iteration 2601 / 3820) loss: 1.702488
# (Epoch 7 / 10) train acc: 0.471000; val_acc: 0.456000
# (Iteration 2701 / 3820) loss: 1.695959
# (Iteration 2801 / 3820) loss: 1.655350
# (Iteration 2901 / 3820) loss: 1.703771
# (Iteration 3001 / 3820) loss: 1.616084
# (Epoch 8 / 10) train acc: 0.469000; val_acc: 0.462000
# (Iteration 3101 / 3820) loss: 1.644321
# (Iteration 3201 / 3820) loss: 1.642978
# (Iteration 3301 / 3820) loss: 1.663475
# (Iteration 3401 / 3820) loss: 1.596616
# (Epoch 9 / 10) train acc: 0.502000; val_acc: 0.466000
# (Iteration 3501 / 3820) loss: 1.588639
# (Iteration 3601 / 3820) loss: 1.566667
# (Iteration 3701 / 3820) loss: 1.673647
# (Iteration 3801 / 3820) loss: 1.506263
# (Epoch 10 / 10) train acc: 0.533000; val_acc: 0.471000
# lr: 3e-05, num_hiddens: 5, p: 0
# (Iteration 1 / 3820) loss: 2.311543
# (Epoch 0 / 10) train acc: 0.107000; val_acc: 0.105000
# (Iteration 101 / 3820) loss: 2.192917
# (Iteration 201 / 3820) loss: 2.046560
# (Iteration 301 / 3820) loss: 2.034606
# (Epoch 1 / 10) train acc: 0.372000; val_acc: 0.398000
# (Iteration 401 / 3820) loss: 1.974783
# (Iteration 501 / 3820) loss: 1.908106
# (Iteration 601 / 3820) loss: 1.808219
# (Iteration 701 / 3820) loss: 1.740956
# (Epoch 2 / 10) train acc: 0.436000; val_acc: 0.428000
# (Iteration 801 / 3820) loss: 1.766653
# (Iteration 901 / 3820) loss: 1.686230
# (Iteration 1001 / 3820) loss: 1.634183
# (Iteration 1101 / 3820) loss: 1.521783
# (Epoch 3 / 10) train acc: 0.482000; val_acc: 0.465000
# (Iteration 1201 / 3820) loss: 1.502548
# (Iteration 1301 / 3820) loss: 1.538621
# (Iteration 1401 / 3820) loss: 1.562093
# (Iteration 1501 / 3820) loss: 1.457898
# (Epoch 4 / 10) train acc: 0.520000; val_acc: 0.473000
# (Iteration 1601 / 3820) loss: 1.518943
# (Iteration 1701 / 3820) loss: 1.491708
# (Iteration 1801 / 3820) loss: 1.490049
# (Iteration 1901 / 3820) loss: 1.355600
# (Epoch 5 / 10) train acc: 0.528000; val_acc: 0.490000
# (Iteration 2001 / 3820) loss: 1.456006
# (Iteration 2101 / 3820) loss: 1.280351
# (Iteration 2201 / 3820) loss: 1.347177
# (Epoch 6 / 10) train acc: 0.552000; val_acc: 0.500000
# (Iteration 2301 / 3820) loss: 1.339441
# (Iteration 2401 / 3820) loss: 1.420413
# (Iteration 2501 / 3820) loss: 1.299785
# (Iteration 2601 / 3820) loss: 1.308642
# (Epoch 7 / 10) train acc: 0.581000; val_acc: 0.499000
# (Iteration 2701 / 3820) loss: 1.235433
# (Iteration 2801 / 3820) loss: 1.236684
# (Iteration 2901 / 3820) loss: 1.406313
# (Iteration 3001 / 3820) loss: 1.272768
# (Epoch 8 / 10) train acc: 0.601000; val_acc: 0.505000
# (Iteration 3101 / 3820) loss: 1.098464
# (Iteration 3201 / 3820) loss: 1.421177
# (Iteration 3301 / 3820) loss: 1.190720
# (Iteration 3401 / 3820) loss: 1.399601
# (Epoch 9 / 10) train acc: 0.558000; val_acc: 0.510000
# (Iteration 3501 / 3820) loss: 1.232716
# (Iteration 3601 / 3820) loss: 1.230138
# (Iteration 3701 / 3820) loss: 1.206998
# (Iteration 3801 / 3820) loss: 1.203509
# (Epoch 10 / 10) train acc: 0.616000; val_acc: 0.513000
# lr: 0.1, num_hiddens: 7, p: 0
# (Iteration 1 / 3820) loss: 2.308259
# (Epoch 0 / 10) train acc: 0.094000; val_acc: 0.113000
# (Iteration 101 / 3820) loss: 1.850209
# (Iteration 201 / 3820) loss: 1.766148
# (Iteration 301 / 3820) loss: 1.800958
# (Epoch 1 / 10) train acc: 0.279000; val_acc: 0.311000
# (Iteration 401 / 3820) loss: 1.692532
# (Iteration 501 / 3820) loss: 1.748317
# (Iteration 601 / 3820) loss: 1.757017
# (Iteration 701 / 3820) loss: 1.656340
# (Epoch 2 / 10) train acc: 0.388000; val_acc: 0.391000
# (Iteration 801 / 3820) loss: 1.680231
# (Iteration 901 / 3820) loss: 1.577755
# (Iteration 1001 / 3820) loss: 1.508591
# (Iteration 1101 / 3820) loss: 1.487418
# (Epoch 3 / 10) train acc: 0.474000; val_acc: 0.435000
# (Iteration 1201 / 3820) loss: 1.573048
# (Iteration 1301 / 3820) loss: 1.555882
# (Iteration 1401 / 3820) loss: 1.476207
# (Iteration 1501 / 3820) loss: 1.595120
# (Epoch 4 / 10) train acc: 0.466000; val_acc: 0.449000
# (Iteration 1601 / 3820) loss: 1.509439
# (Iteration 1701 / 3820) loss: 1.320866
# (Iteration 1801 / 3820) loss: 1.385590
# (Iteration 1901 / 3820) loss: 1.699503
# (Epoch 5 / 10) train acc: 0.464000; val_acc: 0.456000
# (Iteration 2001 / 3820) loss: 1.463110
# (Iteration 2101 / 3820) loss: 1.512419
# (Iteration 2201 / 3820) loss: 1.437560
# (Epoch 6 / 10) train acc: 0.503000; val_acc: 0.491000
# (Iteration 2301 / 3820) loss: 1.427462
# (Iteration 2401 / 3820) loss: 1.280088
# (Iteration 2501 / 3820) loss: 1.516526
# (Iteration 2601 / 3820) loss: 1.322144
# (Epoch 7 / 10) train acc: 0.526000; val_acc: 0.498000
# (Iteration 2701 / 3820) loss: 1.378038
# (Iteration 2801 / 3820) loss: 1.208873
# (Iteration 2901 / 3820) loss: 1.325620
# (Iteration 3001 / 3820) loss: 1.140313
# (Epoch 8 / 10) train acc: 0.517000; val_acc: 0.499000
# (Iteration 3101 / 3820) loss: 1.505769
# (Iteration 3201 / 3820) loss: 1.460589
# (Iteration 3301 / 3820) loss: 1.193449
# (Iteration 3401 / 3820) loss: 1.272860
# (Epoch 9 / 10) train acc: 0.591000; val_acc: 0.509000
# (Iteration 3501 / 3820) loss: 1.363778
# (Iteration 3601 / 3820) loss: 1.523615
# (Iteration 3701 / 3820) loss: 1.211056
# (Iteration 3801 / 3820) loss: 1.341373
# (Epoch 10 / 10) train acc: 0.545000; val_acc: 0.519000
# lr: 0.3, num_hiddens: 7, p: 0
# (Iteration 1 / 3820) loss: 2.316578
# (Epoch 0 / 10) train acc: 0.119000; val_acc: 0.115000
# (Iteration 101 / 3820) loss: 2.308171
# (Iteration 201 / 3820) loss: 2.304829
# (Iteration 301 / 3820) loss: 2.297727
# (Epoch 1 / 10) train acc: 0.090000; val_acc: 0.105000
# (Iteration 401 / 3820) loss: 2.336549
# (Iteration 501 / 3820) loss: 2.318051
# (Iteration 601 / 3820) loss: 2.307123
# (Iteration 701 / 3820) loss: 2.340009
# (Epoch 2 / 10) train acc: 0.089000; val_acc: 0.078000
# (Iteration 801 / 3820) loss: 2.307542
# (Iteration 901 / 3820) loss: 2.319671
# (Iteration 1001 / 3820) loss: 2.324362
# (Iteration 1101 / 3820) loss: 2.295189
# (Epoch 3 / 10) train acc: 0.111000; val_acc: 0.079000
# (Iteration 1201 / 3820) loss: 2.283394
# (Iteration 1301 / 3820) loss: 2.322768
# (Iteration 1401 / 3820) loss: 2.295865
# (Iteration 1501 / 3820) loss: 2.331078
# (Epoch 4 / 10) train acc: 0.092000; val_acc: 0.113000
# (Iteration 1601 / 3820) loss: 2.329864
# (Iteration 1701 / 3820) loss: 2.319144
# (Iteration 1801 / 3820) loss: 2.299195
# (Iteration 1901 / 3820) loss: 2.310782
# (Epoch 5 / 10) train acc: 0.117000; val_acc: 0.079000
# (Iteration 2001 / 3820) loss: 2.304633
# (Iteration 2101 / 3820) loss: 2.314688
# (Iteration 2201 / 3820) loss: 2.299146
# (Epoch 6 / 10) train acc: 0.120000; val_acc: 0.087000
# (Iteration 2301 / 3820) loss: 2.305248
# (Iteration 2401 / 3820) loss: 2.338069
# (Iteration 2501 / 3820) loss: 2.317980
# (Iteration 2601 / 3820) loss: 2.276783
# (Epoch 7 / 10) train acc: 0.112000; val_acc: 0.078000
# (Iteration 2701 / 3820) loss: 2.314377
# (Iteration 2801 / 3820) loss: 2.299864
# (Iteration 2901 / 3820) loss: 2.314891
# (Iteration 3001 / 3820) loss: 2.311224
# (Epoch 8 / 10) train acc: 0.096000; val_acc: 0.119000
# (Iteration 3101 / 3820) loss: 2.312601
# (Iteration 3201 / 3820) loss: 2.310958
# (Iteration 3301 / 3820) loss: 2.313648
# (Iteration 3401 / 3820) loss: 2.324382
# (Epoch 9 / 10) train acc: 0.101000; val_acc: 0.102000
# (Iteration 3501 / 3820) loss: 2.312807
# (Iteration 3601 / 3820) loss: 2.304162
# (Iteration 3701 / 3820) loss: 2.303528
# (Iteration 3801 / 3820) loss: 2.322056
# (Epoch 10 / 10) train acc: 0.118000; val_acc: 0.078000
# lr: 0.001, num_hiddens: 7, p: 0
# (Iteration 1 / 3820) loss: 2.302310
# (Epoch 0 / 10) train acc: 0.134000; val_acc: 0.129000
# (Iteration 101 / 3820) loss: 1.822773
# (Iteration 201 / 3820) loss: 1.806092
# (Iteration 301 / 3820) loss: 1.629292
# (Epoch 1 / 10) train acc: 0.417000; val_acc: 0.431000
# (Iteration 401 / 3820) loss: 1.579474
# (Iteration 501 / 3820) loss: 1.606849
# (Iteration 601 / 3820) loss: 1.484493
# (Iteration 701 / 3820) loss: 1.526150
# (Epoch 2 / 10) train acc: 0.484000; val_acc: 0.487000
# (Iteration 801 / 3820) loss: 1.472782
# (Iteration 901 / 3820) loss: 1.189994
# (Iteration 1001 / 3820) loss: 1.261235
# (Iteration 1101 / 3820) loss: 1.321951
# (Epoch 3 / 10) train acc: 0.527000; val_acc: 0.500000
# (Iteration 1201 / 3820) loss: 1.309289
# (Iteration 1301 / 3820) loss: 1.461708
# (Iteration 1401 / 3820) loss: 1.390534
# (Iteration 1501 / 3820) loss: 1.184679
# (Epoch 4 / 10) train acc: 0.563000; val_acc: 0.516000
# (Iteration 1601 / 3820) loss: 1.335123
# (Iteration 1701 / 3820) loss: 1.125424
# (Iteration 1801 / 3820) loss: 1.102311
# (Iteration 1901 / 3820) loss: 1.084596
# (Epoch 5 / 10) train acc: 0.582000; val_acc: 0.523000
# (Iteration 2001 / 3820) loss: 1.179636
# (Iteration 2101 / 3820) loss: 1.041714
# (Iteration 2201 / 3820) loss: 1.388640
# (Epoch 6 / 10) train acc: 0.578000; val_acc: 0.514000
# (Iteration 2301 / 3820) loss: 1.194356
# (Iteration 2401 / 3820) loss: 1.065003
# (Iteration 2501 / 3820) loss: 1.244552
# (Iteration 2601 / 3820) loss: 1.231037
# (Epoch 7 / 10) train acc: 0.606000; val_acc: 0.537000
# (Iteration 2701 / 3820) loss: 1.128023
# (Iteration 2801 / 3820) loss: 1.083692
# (Iteration 2901 / 3820) loss: 1.092985
# (Iteration 3001 / 3820) loss: 1.231532
# (Epoch 8 / 10) train acc: 0.627000; val_acc: 0.546000
# (Iteration 3101 / 3820) loss: 1.255946
# (Iteration 3201 / 3820) loss: 0.959179
# (Iteration 3301 / 3820) loss: 0.973665
# (Iteration 3401 / 3820) loss: 0.981796
# (Epoch 9 / 10) train acc: 0.641000; val_acc: 0.551000
# (Iteration 3501 / 3820) loss: 0.978904
# (Iteration 3601 / 3820) loss: 1.095874
# (Iteration 3701 / 3820) loss: 1.093164
# (Iteration 3801 / 3820) loss: 1.044671
# (Epoch 10 / 10) train acc: 0.648000; val_acc: 0.554000
# lr: 0.003, num_hiddens: 7, p: 0
# (Iteration 1 / 3820) loss: 2.295815
# (Epoch 0 / 10) train acc: 0.106000; val_acc: 0.119000
# (Iteration 101 / 3820) loss: 1.904421
# (Iteration 201 / 3820) loss: 1.744609
# (Iteration 301 / 3820) loss: 1.580352
# (Epoch 1 / 10) train acc: 0.436000; val_acc: 0.428000
# (Iteration 401 / 3820) loss: 1.526358
# (Iteration 501 / 3820) loss: 1.407389
# (Iteration 601 / 3820) loss: 1.502732
# (Iteration 701 / 3820) loss: 1.446173
# (Epoch 2 / 10) train acc: 0.520000; val_acc: 0.485000
# (Iteration 801 / 3820) loss: 1.508292
# (Iteration 901 / 3820) loss: 1.366520
# (Iteration 1001 / 3820) loss: 1.610306
# (Iteration 1101 / 3820) loss: 1.516081
# (Epoch 3 / 10) train acc: 0.490000; val_acc: 0.498000
# (Iteration 1201 / 3820) loss: 1.312885
# (Iteration 1301 / 3820) loss: 1.383600
# (Iteration 1401 / 3820) loss: 1.355021
# (Iteration 1501 / 3820) loss: 1.227999
# (Epoch 4 / 10) train acc: 0.514000; val_acc: 0.503000
# (Iteration 1601 / 3820) loss: 1.193224
# (Iteration 1701 / 3820) loss: 1.555523
# (Iteration 1801 / 3820) loss: 1.491183
# (Iteration 1901 / 3820) loss: 1.078341
# (Epoch 5 / 10) train acc: 0.579000; val_acc: 0.525000
# (Iteration 2001 / 3820) loss: 1.148986
# (Iteration 2101 / 3820) loss: 1.323070
# (Iteration 2201 / 3820) loss: 1.161828
# (Epoch 6 / 10) train acc: 0.566000; val_acc: 0.538000
# (Iteration 2301 / 3820) loss: 1.199966
# (Iteration 2401 / 3820) loss: 1.187394
# (Iteration 2501 / 3820) loss: 0.965336
# (Iteration 2601 / 3820) loss: 1.329721
# (Epoch 7 / 10) train acc: 0.622000; val_acc: 0.540000
# (Iteration 2701 / 3820) loss: 1.131222
# (Iteration 2801 / 3820) loss: 1.258082
# (Iteration 2901 / 3820) loss: 1.045049
# (Iteration 3001 / 3820) loss: 1.008961
# (Epoch 8 / 10) train acc: 0.645000; val_acc: 0.541000
# (Iteration 3101 / 3820) loss: 0.925754
# (Iteration 3201 / 3820) loss: 1.126189
# (Iteration 3301 / 3820) loss: 1.000045
# (Iteration 3401 / 3820) loss: 1.027660
# (Epoch 9 / 10) train acc: 0.624000; val_acc: 0.547000
# (Iteration 3501 / 3820) loss: 0.955387
# (Iteration 3601 / 3820) loss: 0.938598
# (Iteration 3701 / 3820) loss: 1.186225
# (Iteration 3801 / 3820) loss: 1.225620
# (Epoch 10 / 10) train acc: 0.662000; val_acc: 0.542000
# lr: 1e-05, num_hiddens: 7, p: 0
# (Iteration 1 / 3820) loss: 2.300139
# (Epoch 0 / 10) train acc: 0.091000; val_acc: 0.100000
# (Iteration 101 / 3820) loss: 2.269301
# (Iteration 201 / 3820) loss: 2.220748
# (Iteration 301 / 3820) loss: 2.199623
# (Epoch 1 / 10) train acc: 0.331000; val_acc: 0.310000
# (Iteration 401 / 3820) loss: 2.134779
# (Iteration 501 / 3820) loss: 2.123277
# (Iteration 601 / 3820) loss: 2.093071
# (Iteration 701 / 3820) loss: 2.069637
# (Epoch 2 / 10) train acc: 0.341000; val_acc: 0.355000
# (Iteration 801 / 3820) loss: 2.033303
# (Iteration 901 / 3820) loss: 1.962314
# (Iteration 1001 / 3820) loss: 1.977535
# (Iteration 1101 / 3820) loss: 1.937579
# (Epoch 3 / 10) train acc: 0.397000; val_acc: 0.385000
# (Iteration 1201 / 3820) loss: 1.901618
# (Iteration 1301 / 3820) loss: 1.864013
# (Iteration 1401 / 3820) loss: 1.896776
# (Iteration 1501 / 3820) loss: 1.882348
# (Epoch 4 / 10) train acc: 0.410000; val_acc: 0.414000
# (Iteration 1601 / 3820) loss: 1.840653
# (Iteration 1701 / 3820) loss: 1.821556
# (Iteration 1801 / 3820) loss: 1.797468
# (Iteration 1901 / 3820) loss: 1.783974
# (Epoch 5 / 10) train acc: 0.435000; val_acc: 0.423000
# (Iteration 2001 / 3820) loss: 1.812663
# (Iteration 2101 / 3820) loss: 1.803440
# (Iteration 2201 / 3820) loss: 1.709745
# (Epoch 6 / 10) train acc: 0.439000; val_acc: 0.442000
# (Iteration 2301 / 3820) loss: 1.692391
# (Iteration 2401 / 3820) loss: 1.659422
# (Iteration 2501 / 3820) loss: 1.701021
# (Iteration 2601 / 3820) loss: 1.734416
# (Epoch 7 / 10) train acc: 0.473000; val_acc: 0.438000
# (Iteration 2701 / 3820) loss: 1.719415
# (Iteration 2801 / 3820) loss: 1.686578
# (Iteration 2901 / 3820) loss: 1.651691
# (Iteration 3001 / 3820) loss: 1.673121
# (Epoch 8 / 10) train acc: 0.474000; val_acc: 0.443000
# (Iteration 3101 / 3820) loss: 1.671247
# (Iteration 3201 / 3820) loss: 1.617621
# (Iteration 3301 / 3820) loss: 1.649069
# (Iteration 3401 / 3820) loss: 1.558568
# (Epoch 9 / 10) train acc: 0.488000; val_acc: 0.454000
# (Iteration 3501 / 3820) loss: 1.679570
# (Iteration 3601 / 3820) loss: 1.634513
# (Iteration 3701 / 3820) loss: 1.533784
# (Iteration 3801 / 3820) loss: 1.548495
# (Epoch 10 / 10) train acc: 0.495000; val_acc: 0.467000
# lr: 3e-05, num_hiddens: 7, p: 0
# (Iteration 1 / 3820) loss: 2.308163
# (Epoch 0 / 10) train acc: 0.112000; val_acc: 0.077000
# (Iteration 101 / 3820) loss: 2.209266
# (Iteration 201 / 3820) loss: 2.028180
# (Iteration 301 / 3820) loss: 2.032005
# (Epoch 1 / 10) train acc: 0.359000; val_acc: 0.364000
# (Iteration 401 / 3820) loss: 1.911342
# (Iteration 501 / 3820) loss: 1.839057
# (Iteration 601 / 3820) loss: 1.904920
# (Iteration 701 / 3820) loss: 1.841775
# (Epoch 2 / 10) train acc: 0.448000; val_acc: 0.430000
# (Iteration 801 / 3820) loss: 1.781135
# (Iteration 901 / 3820) loss: 1.729636
# (Iteration 1001 / 3820) loss: 1.600631
# (Iteration 1101 / 3820) loss: 1.641089
# (Epoch 3 / 10) train acc: 0.493000; val_acc: 0.454000
# (Iteration 1201 / 3820) loss: 1.565039
# (Iteration 1301 / 3820) loss: 1.566549
# (Iteration 1401 / 3820) loss: 1.554125
# (Iteration 1501 / 3820) loss: 1.696876
# (Epoch 4 / 10) train acc: 0.496000; val_acc: 0.457000
# (Iteration 1601 / 3820) loss: 1.505929
# (Iteration 1701 / 3820) loss: 1.609125
# (Iteration 1801 / 3820) loss: 1.494559
# (Iteration 1901 / 3820) loss: 1.449612
# (Epoch 5 / 10) train acc: 0.524000; val_acc: 0.472000
# (Iteration 2001 / 3820) loss: 1.423311
# (Iteration 2101 / 3820) loss: 1.366980
# (Iteration 2201 / 3820) loss: 1.320437
# (Epoch 6 / 10) train acc: 0.528000; val_acc: 0.472000
# (Iteration 2301 / 3820) loss: 1.378064
# (Iteration 2401 / 3820) loss: 1.319724
# (Iteration 2501 / 3820) loss: 1.378757
# (Iteration 2601 / 3820) loss: 1.213038
# (Epoch 7 / 10) train acc: 0.546000; val_acc: 0.477000
# (Iteration 2701 / 3820) loss: 1.299015
# (Iteration 2801 / 3820) loss: 1.353773
# (Iteration 2901 / 3820) loss: 1.279449
# (Iteration 3001 / 3820) loss: 1.399025
# (Epoch 8 / 10) train acc: 0.576000; val_acc: 0.488000
# (Iteration 3101 / 3820) loss: 1.233853
# (Iteration 3201 / 3820) loss: 1.391328
# (Iteration 3301 / 3820) loss: 1.205917
# (Iteration 3401 / 3820) loss: 1.092381
# (Epoch 9 / 10) train acc: 0.587000; val_acc: 0.507000
# (Iteration 3501 / 3820) loss: 1.278267
# (Iteration 3601 / 3820) loss: 1.397904
# (Iteration 3701 / 3820) loss: 1.184014
# (Iteration 3801 / 3820) loss: 1.242897
# (Epoch 10 / 10) train acc: 0.623000; val_acc: 0.498000
# lr: 0.1, num_hiddens: 10, p: 0
# (Iteration 1 / 3820) loss: 2.308836
# (Epoch 0 / 10) train acc: 0.111000; val_acc: 0.105000
# (Iteration 101 / 3820) loss: 2.242526
# (Iteration 201 / 3820) loss: 2.158244
# (Iteration 301 / 3820) loss: 2.021740
# (Epoch 1 / 10) train acc: 0.220000; val_acc: 0.243000
# (Iteration 401 / 3820) loss: 1.944880
# (Iteration 501 / 3820) loss: 1.902371
# (Iteration 601 / 3820) loss: 2.006151
# (Iteration 701 / 3820) loss: 1.825104
# (Epoch 2 / 10) train acc: 0.273000; val_acc: 0.247000
# (Iteration 801 / 3820) loss: 1.768448
# (Iteration 901 / 3820) loss: 1.689764
# (Iteration 1001 / 3820) loss: 1.830325
# (Iteration 1101 / 3820) loss: 1.708291
# (Epoch 3 / 10) train acc: 0.324000; val_acc: 0.338000
# (Iteration 1201 / 3820) loss: 1.677906
# (Iteration 1301 / 3820) loss: 1.618961
# (Iteration 1401 / 3820) loss: 1.673292
# (Iteration 1501 / 3820) loss: 1.742135
# (Epoch 4 / 10) train acc: 0.393000; val_acc: 0.378000
# (Iteration 1601 / 3820) loss: 1.583254
# (Iteration 1701 / 3820) loss: 1.740116
# (Iteration 1801 / 3820) loss: 1.669999
# (Iteration 1901 / 3820) loss: 1.477619
# (Epoch 5 / 10) train acc: 0.402000; val_acc: 0.431000
# (Iteration 2001 / 3820) loss: 1.668330
# (Iteration 2101 / 3820) loss: 1.472123
# (Iteration 2201 / 3820) loss: 1.459423
# (Epoch 6 / 10) train acc: 0.444000; val_acc: 0.441000
# (Iteration 2301 / 3820) loss: 1.617014
# (Iteration 2401 / 3820) loss: 1.358937
# (Iteration 2501 / 3820) loss: 1.506862
# (Iteration 2601 / 3820) loss: 1.293500
# (Epoch 7 / 10) train acc: 0.440000; val_acc: 0.434000
# (Iteration 2701 / 3820) loss: 1.717969
# (Iteration 2801 / 3820) loss: 1.637688
# (Iteration 2901 / 3820) loss: 1.579751
# (Iteration 3001 / 3820) loss: 1.547583
# (Epoch 8 / 10) train acc: 0.450000; val_acc: 0.457000
# (Iteration 3101 / 3820) loss: 1.450079
# (Iteration 3201 / 3820) loss: 1.508968
# (Iteration 3301 / 3820) loss: 1.602665
# (Iteration 3401 / 3820) loss: 1.650767
# (Epoch 9 / 10) train acc: 0.450000; val_acc: 0.449000
# (Iteration 3501 / 3820) loss: 1.500978
# (Iteration 3601 / 3820) loss: 1.434430
# (Iteration 3701 / 3820) loss: 1.540323
# (Iteration 3801 / 3820) loss: 1.472475
# (Epoch 10 / 10) train acc: 0.491000; val_acc: 0.464000
# lr: 0.3, num_hiddens: 10, p: 0
# (Iteration 1 / 3820) loss: 2.309113
# (Epoch 0 / 10) train acc: 0.112000; val_acc: 0.105000
# (Iteration 101 / 3820) loss: 2.319536
# (Iteration 201 / 3820) loss: 2.340590
# (Iteration 301 / 3820) loss: 2.321835
# (Epoch 1 / 10) train acc: 0.107000; val_acc: 0.107000
# (Iteration 401 / 3820) loss: 2.315486
# (Iteration 501 / 3820) loss: 2.330099
# (Iteration 601 / 3820) loss: 2.322814
# (Iteration 701 / 3820) loss: 2.302648
# (Epoch 2 / 10) train acc: 0.101000; val_acc: 0.105000
# (Iteration 801 / 3820) loss: 2.321818
# (Iteration 901 / 3820) loss: 2.326476
# (Iteration 1001 / 3820) loss: 2.304222
# (Iteration 1101 / 3820) loss: 2.305723
# (Epoch 3 / 10) train acc: 0.110000; val_acc: 0.098000
# (Iteration 1201 / 3820) loss: 2.285403
# (Iteration 1301 / 3820) loss: 2.299541
# (Iteration 1401 / 3820) loss: 2.331897
# (Iteration 1501 / 3820) loss: 2.296268
# (Epoch 4 / 10) train acc: 0.093000; val_acc: 0.102000
# (Iteration 1601 / 3820) loss: 2.322349
# (Iteration 1701 / 3820) loss: 2.312811
# (Iteration 1801 / 3820) loss: 2.302685
# (Iteration 1901 / 3820) loss: 2.284946
# (Epoch 5 / 10) train acc: 0.110000; val_acc: 0.119000
# (Iteration 2001 / 3820) loss: 2.358350
# (Iteration 2101 / 3820) loss: 2.318675
# (Iteration 2201 / 3820) loss: 2.302864
# (Epoch 6 / 10) train acc: 0.108000; val_acc: 0.102000
# (Iteration 2301 / 3820) loss: 2.297288
# (Iteration 2401 / 3820) loss: 2.316446
# (Iteration 2501 / 3820) loss: 2.340051
# (Iteration 2601 / 3820) loss: 2.310909
# (Epoch 7 / 10) train acc: 0.124000; val_acc: 0.105000
# (Iteration 2701 / 3820) loss: 2.296985
# (Iteration 2801 / 3820) loss: 2.286678
# (Iteration 2901 / 3820) loss: 2.320373
# (Iteration 3001 / 3820) loss: 2.314345
# (Epoch 8 / 10) train acc: 0.103000; val_acc: 0.098000
# (Iteration 3101 / 3820) loss: 2.324729
# (Iteration 3201 / 3820) loss: 2.318458
# (Iteration 3301 / 3820) loss: 2.303609
# (Iteration 3401 / 3820) loss: 2.328937
# (Epoch 9 / 10) train acc: 0.084000; val_acc: 0.098000
# (Iteration 3501 / 3820) loss: 2.347198
# (Iteration 3601 / 3820) loss: 2.318427
# (Iteration 3701 / 3820) loss: 2.315502
# (Iteration 3801 / 3820) loss: 2.306026
# (Epoch 10 / 10) train acc: 0.098000; val_acc: 0.119000
# lr: 0.001, num_hiddens: 10, p: 0
# (Iteration 1 / 3820) loss: 2.302050
# (Epoch 0 / 10) train acc: 0.090000; val_acc: 0.107000
# (Iteration 101 / 3820) loss: 1.974363
# (Iteration 201 / 3820) loss: 1.727131
# (Iteration 301 / 3820) loss: 1.658174
# (Epoch 1 / 10) train acc: 0.375000; val_acc: 0.366000
# (Iteration 401 / 3820) loss: 1.805245
# (Iteration 501 / 3820) loss: 1.713552
# (Iteration 601 / 3820) loss: 1.902690
# (Iteration 701 / 3820) loss: 1.680341
# (Epoch 2 / 10) train acc: 0.442000; val_acc: 0.457000
# (Iteration 801 / 3820) loss: 1.690808
# (Iteration 901 / 3820) loss: 1.407733
# (Iteration 1001 / 3820) loss: 1.438531
# (Iteration 1101 / 3820) loss: 1.405747
# (Epoch 3 / 10) train acc: 0.493000; val_acc: 0.497000
# (Iteration 1201 / 3820) loss: 1.335960
# (Iteration 1301 / 3820) loss: 1.400711
# (Iteration 1401 / 3820) loss: 1.422384
# (Iteration 1501 / 3820) loss: 1.208745
# (Epoch 4 / 10) train acc: 0.522000; val_acc: 0.476000
# (Iteration 1601 / 3820) loss: 1.392879
# (Iteration 1701 / 3820) loss: 1.337008
# (Iteration 1801 / 3820) loss: 1.358537
# (Iteration 1901 / 3820) loss: 1.251831
# (Epoch 5 / 10) train acc: 0.544000; val_acc: 0.511000
# (Iteration 2001 / 3820) loss: 1.285019
# (Iteration 2101 / 3820) loss: 1.574795
# (Iteration 2201 / 3820) loss: 1.340887
# (Epoch 6 / 10) train acc: 0.563000; val_acc: 0.514000
# (Iteration 2301 / 3820) loss: 1.466430
# (Iteration 2401 / 3820) loss: 1.068843
# (Iteration 2501 / 3820) loss: 1.324520
# (Iteration 2601 / 3820) loss: 1.191332
# (Epoch 7 / 10) train acc: 0.587000; val_acc: 0.526000
# (Iteration 2701 / 3820) loss: 1.134370
# (Iteration 2801 / 3820) loss: 1.081941
# (Iteration 2901 / 3820) loss: 1.007121
# (Iteration 3001 / 3820) loss: 1.215625
# (Epoch 8 / 10) train acc: 0.602000; val_acc: 0.527000
# (Iteration 3101 / 3820) loss: 1.204029
# (Iteration 3201 / 3820) loss: 1.237023
# (Iteration 3301 / 3820) loss: 1.020913
# (Iteration 3401 / 3820) loss: 1.093689
# (Epoch 9 / 10) train acc: 0.599000; val_acc: 0.518000
# (Iteration 3501 / 3820) loss: 1.000756
# (Iteration 3601 / 3820) loss: 0.913963
# (Iteration 3701 / 3820) loss: 1.333521
# (Iteration 3801 / 3820) loss: 1.047683
# (Epoch 10 / 10) train acc: 0.624000; val_acc: 0.541000
# lr: 0.003, num_hiddens: 10, p: 0
# (Iteration 1 / 3820) loss: 2.311554
# (Epoch 0 / 10) train acc: 0.101000; val_acc: 0.118000
# (Iteration 101 / 3820) loss: 1.950161
# (Iteration 201 / 3820) loss: 1.742946
# (Iteration 301 / 3820) loss: 1.666791
# (Epoch 1 / 10) train acc: 0.404000; val_acc: 0.381000
# (Iteration 401 / 3820) loss: 1.636008
# (Iteration 501 / 3820) loss: 1.723125
# (Iteration 601 / 3820) loss: 1.618714
# (Iteration 701 / 3820) loss: 1.514171
# (Epoch 2 / 10) train acc: 0.426000; val_acc: 0.441000
# (Iteration 801 / 3820) loss: 1.702164
# (Iteration 901 / 3820) loss: 1.456198
# (Iteration 1001 / 3820) loss: 1.562641
# (Iteration 1101 / 3820) loss: 1.463694
# (Epoch 3 / 10) train acc: 0.514000; val_acc: 0.470000
# (Iteration 1201 / 3820) loss: 1.491615
# (Iteration 1301 / 3820) loss: 1.469056
# (Iteration 1401 / 3820) loss: 1.493045
# (Iteration 1501 / 3820) loss: 1.407664
# (Epoch 4 / 10) train acc: 0.513000; val_acc: 0.490000
# (Iteration 1601 / 3820) loss: 1.459756
# (Iteration 1701 / 3820) loss: 1.385471
# (Iteration 1801 / 3820) loss: 1.585676
# (Iteration 1901 / 3820) loss: 1.333087
# (Epoch 5 / 10) train acc: 0.534000; val_acc: 0.506000
# (Iteration 2001 / 3820) loss: 1.497530
# (Iteration 2101 / 3820) loss: 1.337054
# (Iteration 2201 / 3820) loss: 1.472065
# (Epoch 6 / 10) train acc: 0.535000; val_acc: 0.517000
# (Iteration 2301 / 3820) loss: 1.235304
# (Iteration 2401 / 3820) loss: 1.159475
# (Iteration 2501 / 3820) loss: 1.216080
# (Iteration 2601 / 3820) loss: 1.291516
# (Epoch 7 / 10) train acc: 0.557000; val_acc: 0.517000
# (Iteration 2701 / 3820) loss: 1.103612
# (Iteration 2801 / 3820) loss: 1.211347
# (Iteration 2901 / 3820) loss: 1.112643
# (Iteration 3001 / 3820) loss: 1.122646
# (Epoch 8 / 10) train acc: 0.582000; val_acc: 0.541000
# (Iteration 3101 / 3820) loss: 1.060865
# (Iteration 3201 / 3820) loss: 1.177479
# (Iteration 3301 / 3820) loss: 1.194643
# (Iteration 3401 / 3820) loss: 1.160874
# (Epoch 9 / 10) train acc: 0.616000; val_acc: 0.534000
# (Iteration 3501 / 3820) loss: 1.241908
# (Iteration 3601 / 3820) loss: 1.135018
# (Iteration 3701 / 3820) loss: 1.108486
# (Iteration 3801 / 3820) loss: 1.216480
# (Epoch 10 / 10) train acc: 0.631000; val_acc: 0.536000
# lr: 1e-05, num_hiddens: 10, p: 0
# (Iteration 1 / 3820) loss: 2.299668
# (Epoch 0 / 10) train acc: 0.101000; val_acc: 0.098000
# (Iteration 101 / 3820) loss: 2.301748
# (Iteration 201 / 3820) loss: 2.269099
# (Iteration 301 / 3820) loss: 2.229396
# (Epoch 1 / 10) train acc: 0.251000; val_acc: 0.251000
# (Iteration 401 / 3820) loss: 2.194922
# (Iteration 501 / 3820) loss: 2.175236
# (Iteration 601 / 3820) loss: 2.155215
# (Iteration 701 / 3820) loss: 2.100221
# (Epoch 2 / 10) train acc: 0.330000; val_acc: 0.296000
# (Iteration 801 / 3820) loss: 2.053252
# (Iteration 901 / 3820) loss: 2.036781
# (Iteration 1001 / 3820) loss: 2.016548
# (Iteration 1101 / 3820) loss: 2.004633
# (Epoch 3 / 10) train acc: 0.333000; val_acc: 0.360000
# (Iteration 1201 / 3820) loss: 1.881443
# (Iteration 1301 / 3820) loss: 1.985400
# (Iteration 1401 / 3820) loss: 1.947244
# (Iteration 1501 / 3820) loss: 1.911697
# (Epoch 4 / 10) train acc: 0.369000; val_acc: 0.373000
# (Iteration 1601 / 3820) loss: 1.991756
# (Iteration 1701 / 3820) loss: 1.882661
# (Iteration 1801 / 3820) loss: 1.769673
# (Iteration 1901 / 3820) loss: 1.874180
# (Epoch 5 / 10) train acc: 0.425000; val_acc: 0.397000
# (Iteration 2001 / 3820) loss: 1.772053
# (Iteration 2101 / 3820) loss: 1.864251
# (Iteration 2201 / 3820) loss: 1.774642
# (Epoch 6 / 10) train acc: 0.432000; val_acc: 0.430000
# (Iteration 2301 / 3820) loss: 1.814989
# (Iteration 2401 / 3820) loss: 1.772135
# (Iteration 2501 / 3820) loss: 1.774180
# (Iteration 2601 / 3820) loss: 1.755360
# (Epoch 7 / 10) train acc: 0.439000; val_acc: 0.443000
# (Iteration 2701 / 3820) loss: 1.782033
# (Iteration 2801 / 3820) loss: 1.789567
# (Iteration 2901 / 3820) loss: 1.801649
# (Iteration 3001 / 3820) loss: 1.741306
# (Epoch 8 / 10) train acc: 0.461000; val_acc: 0.451000
# (Iteration 3101 / 3820) loss: 1.814283
# (Iteration 3201 / 3820) loss: 1.677649
# (Iteration 3301 / 3820) loss: 1.782781
# (Iteration 3401 / 3820) loss: 1.648446
# (Epoch 9 / 10) train acc: 0.474000; val_acc: 0.471000
# (Iteration 3501 / 3820) loss: 1.701985
# (Iteration 3601 / 3820) loss: 1.602522
# (Iteration 3701 / 3820) loss: 1.604991
# (Iteration 3801 / 3820) loss: 1.649526
# (Epoch 10 / 10) train acc: 0.488000; val_acc: 0.474000
# lr: 3e-05, num_hiddens: 10, p: 0
# (Iteration 1 / 3820) loss: 2.302586
# (Epoch 0 / 10) train acc: 0.103000; val_acc: 0.104000
# (Iteration 101 / 3820) loss: 2.225936
# (Iteration 201 / 3820) loss: 2.140573
# (Iteration 301 / 3820) loss: 2.002646
# (Epoch 1 / 10) train acc: 0.320000; val_acc: 0.351000
# (Iteration 401 / 3820) loss: 2.017499
# (Iteration 501 / 3820) loss: 1.893161
# (Iteration 601 / 3820) loss: 1.854577
# (Iteration 701 / 3820) loss: 1.862024
# (Epoch 2 / 10) train acc: 0.435000; val_acc: 0.423000
# (Iteration 801 / 3820) loss: 1.727043
# (Iteration 901 / 3820) loss: 1.779208
# (Iteration 1001 / 3820) loss: 1.740769
# (Iteration 1101 / 3820) loss: 1.682171
# (Epoch 3 / 10) train acc: 0.436000; val_acc: 0.441000
# (Iteration 1201 / 3820) loss: 1.754584
# (Iteration 1301 / 3820) loss: 1.664053
# (Iteration 1401 / 3820) loss: 1.536599
# (Iteration 1501 / 3820) loss: 1.644359
# (Epoch 4 / 10) train acc: 0.476000; val_acc: 0.441000
# (Iteration 1601 / 3820) loss: 1.462311
# (Iteration 1701 / 3820) loss: 1.521494
# (Iteration 1801 / 3820) loss: 1.492292
# (Iteration 1901 / 3820) loss: 1.538356
# (Epoch 5 / 10) train acc: 0.509000; val_acc: 0.464000
# (Iteration 2001 / 3820) loss: 1.480363
# (Iteration 2101 / 3820) loss: 1.357636
# (Iteration 2201 / 3820) loss: 1.485028
# (Epoch 6 / 10) train acc: 0.524000; val_acc: 0.482000
# (Iteration 2301 / 3820) loss: 1.420168
# (Iteration 2401 / 3820) loss: 1.474895
# (Iteration 2501 / 3820) loss: 1.471213
# (Iteration 2601 / 3820) loss: 1.539036
# (Epoch 7 / 10) train acc: 0.533000; val_acc: 0.478000
# (Iteration 2701 / 3820) loss: 1.280870
# (Iteration 2801 / 3820) loss: 1.323661
# (Iteration 2901 / 3820) loss: 1.561585
# (Iteration 3001 / 3820) loss: 1.346440
# (Epoch 8 / 10) train acc: 0.558000; val_acc: 0.486000
# (Iteration 3101 / 3820) loss: 1.358969
# (Iteration 3201 / 3820) loss: 1.267906
# (Iteration 3301 / 3820) loss: 1.431704
# (Iteration 3401 / 3820) loss: 1.527482
# (Epoch 9 / 10) train acc: 0.599000; val_acc: 0.484000
# (Iteration 3501 / 3820) loss: 1.321787
# (Iteration 3601 / 3820) loss: 1.244576
# (Iteration 3701 / 3820) loss: 1.275027
# (Iteration 3801 / 3820) loss: 1.310490
# (Epoch 10 / 10) train acc: 0.616000; val_acc: 0.482000
# lr: 0.1, num_hiddens: 15, p: 0
# (Iteration 1 / 3820) loss: 2.301614
# (Epoch 0 / 10) train acc: 0.093000; val_acc: 0.079000
# (Iteration 101 / 3820) loss: 2.306390
# (Iteration 201 / 3820) loss: 2.310973
# (Iteration 301 / 3820) loss: 2.289542
# (Epoch 1 / 10) train acc: 0.102000; val_acc: 0.105000
# (Iteration 401 / 3820) loss: 2.310648
# (Iteration 501 / 3820) loss: 2.325577
# (Iteration 601 / 3820) loss: 2.308602
# (Iteration 701 / 3820) loss: 2.303210
# (Epoch 2 / 10) train acc: 0.087000; val_acc: 0.079000
# (Iteration 801 / 3820) loss: 2.324226
# (Iteration 901 / 3820) loss: 2.303719
# (Iteration 1001 / 3820) loss: 2.299878
# (Iteration 1101 / 3820) loss: 2.286190
# (Epoch 3 / 10) train acc: 0.118000; val_acc: 0.119000
# (Iteration 1201 / 3820) loss: 2.306317
# (Iteration 1301 / 3820) loss: 2.315857
# (Iteration 1401 / 3820) loss: 2.311154
# (Iteration 1501 / 3820) loss: 2.311830
# (Epoch 4 / 10) train acc: 0.106000; val_acc: 0.113000
# (Iteration 1601 / 3820) loss: 2.309050
# (Iteration 1701 / 3820) loss: 2.296569
# (Iteration 1801 / 3820) loss: 2.299001
# (Iteration 1901 / 3820) loss: 2.306779
# (Epoch 5 / 10) train acc: 0.095000; val_acc: 0.113000
# (Iteration 2001 / 3820) loss: 2.300701
# (Iteration 2101 / 3820) loss: 2.300758
# (Iteration 2201 / 3820) loss: 2.317573
# (Epoch 6 / 10) train acc: 0.085000; val_acc: 0.087000
# (Iteration 2301 / 3820) loss: 2.313819
# (Iteration 2401 / 3820) loss: 2.297013
# (Iteration 2501 / 3820) loss: 2.337078
# (Iteration 2601 / 3820) loss: 2.299203
# (Epoch 7 / 10) train acc: 0.097000; val_acc: 0.119000
# (Iteration 2701 / 3820) loss: 2.307353
# (Iteration 2801 / 3820) loss: 2.308105
# (Iteration 2901 / 3820) loss: 2.303223
# (Iteration 3001 / 3820) loss: 2.303399
# (Epoch 8 / 10) train acc: 0.102000; val_acc: 0.119000
# (Iteration 3101 / 3820) loss: 2.305918
# (Iteration 3201 / 3820) loss: 2.303564
# (Iteration 3301 / 3820) loss: 2.307718
# (Iteration 3401 / 3820) loss: 2.309112
# (Epoch 9 / 10) train acc: 0.098000; val_acc: 0.107000
# (Iteration 3501 / 3820) loss: 2.322689
# (Iteration 3601 / 3820) loss: 2.312692
# (Iteration 3701 / 3820) loss: 2.299303
# (Iteration 3801 / 3820) loss: 2.315096
# (Epoch 10 / 10) train acc: 0.087000; val_acc: 0.105000
# lr: 0.3, num_hiddens: 15, p: 0
# (Iteration 1 / 3820) loss: 2.308254
# (Epoch 0 / 10) train acc: 0.100000; val_acc: 0.119000
# (Iteration 101 / 3820) loss: 2.297035
# (Iteration 201 / 3820) loss: 2.291787
# (Iteration 301 / 3820) loss: 2.333557
# (Epoch 1 / 10) train acc: 0.091000; val_acc: 0.119000
# (Iteration 401 / 3820) loss: 2.316080
# (Iteration 501 / 3820) loss: 2.326150
# (Iteration 601 / 3820) loss: 2.353306
# (Iteration 701 / 3820) loss: 2.321898
# (Epoch 2 / 10) train acc: 0.093000; val_acc: 0.113000
# (Iteration 801 / 3820) loss: 2.316965
# (Iteration 901 / 3820) loss: 2.314252
# (Iteration 1001 / 3820) loss: 2.340107
# (Iteration 1101 / 3820) loss: 2.305849
# (Epoch 3 / 10) train acc: 0.086000; val_acc: 0.078000
# (Iteration 1201 / 3820) loss: 2.318193
# (Iteration 1301 / 3820) loss: 2.304561
# (Iteration 1401 / 3820) loss: 2.330165
# (Iteration 1501 / 3820) loss: 2.306474
# (Epoch 4 / 10) train acc: 0.092000; val_acc: 0.079000
# (Iteration 1601 / 3820) loss: 2.330870
# (Iteration 1701 / 3820) loss: 2.310310
# (Iteration 1801 / 3820) loss: 2.298056
# (Iteration 1901 / 3820) loss: 2.312354
# (Epoch 5 / 10) train acc: 0.101000; val_acc: 0.105000
# (Iteration 2001 / 3820) loss: 2.301527
# (Iteration 2101 / 3820) loss: 2.285814
# (Iteration 2201 / 3820) loss: 2.316472
# (Epoch 6 / 10) train acc: 0.095000; val_acc: 0.078000
# (Iteration 2301 / 3820) loss: 2.311458
# (Iteration 2401 / 3820) loss: 2.311977
# (Iteration 2501 / 3820) loss: 2.323627
# (Iteration 2601 / 3820) loss: 2.303611
# (Epoch 7 / 10) train acc: 0.084000; val_acc: 0.087000
# (Iteration 2701 / 3820) loss: 2.323570
# (Iteration 2801 / 3820) loss: 2.357934
# (Iteration 2901 / 3820) loss: 2.311017
# (Iteration 3001 / 3820) loss: 2.330045
# (Epoch 8 / 10) train acc: 0.095000; val_acc: 0.119000
# (Iteration 3101 / 3820) loss: 2.299370
# (Iteration 3201 / 3820) loss: 2.272601
# (Iteration 3301 / 3820) loss: 2.317639
# (Iteration 3401 / 3820) loss: 2.323549
# (Epoch 9 / 10) train acc: 0.081000; val_acc: 0.107000
# (Iteration 3501 / 3820) loss: 2.326454
# (Iteration 3601 / 3820) loss: 2.325767
# (Iteration 3701 / 3820) loss: 2.334542
# (Iteration 3801 / 3820) loss: 2.296356
# (Epoch 10 / 10) train acc: 0.097000; val_acc: 0.102000
# lr: 0.001, num_hiddens: 15, p: 0
# (Iteration 1 / 3820) loss: 2.295226
# (Epoch 0 / 10) train acc: 0.097000; val_acc: 0.096000
# (Iteration 101 / 3820) loss: 1.942910
# (Iteration 201 / 3820) loss: 1.919333
# (Iteration 301 / 3820) loss: 1.870285
# (Epoch 1 / 10) train acc: 0.330000; val_acc: 0.348000
# (Iteration 401 / 3820) loss: 1.830999
# (Iteration 501 / 3820) loss: 1.645779
# (Iteration 601 / 3820) loss: 1.653617
# (Iteration 701 / 3820) loss: 1.638638
# (Epoch 2 / 10) train acc: 0.356000; val_acc: 0.390000
# (Iteration 801 / 3820) loss: 1.611391
# (Iteration 901 / 3820) loss: 1.522802
# (Iteration 1001 / 3820) loss: 1.493893
# (Iteration 1101 / 3820) loss: 1.557978
# (Epoch 3 / 10) train acc: 0.450000; val_acc: 0.447000
# (Iteration 1201 / 3820) loss: 1.536443
# (Iteration 1301 / 3820) loss: 1.679695
# (Iteration 1401 / 3820) loss: 1.614115
# (Iteration 1501 / 3820) loss: 1.442642
# (Epoch 4 / 10) train acc: 0.476000; val_acc: 0.440000
# (Iteration 1601 / 3820) loss: 1.470761
# (Iteration 1701 / 3820) loss: 1.317129
# (Iteration 1801 / 3820) loss: 1.608512
# (Iteration 1901 / 3820) loss: 1.458741
# (Epoch 5 / 10) train acc: 0.465000; val_acc: 0.494000
# (Iteration 2001 / 3820) loss: 1.673721
# (Iteration 2101 / 3820) loss: 1.438621
# (Iteration 2201 / 3820) loss: 1.257184
# (Epoch 6 / 10) train acc: 0.564000; val_acc: 0.514000
# (Iteration 2301 / 3820) loss: 1.520878
# (Iteration 2401 / 3820) loss: 1.437207
# (Iteration 2501 / 3820) loss: 1.251303
# (Iteration 2601 / 3820) loss: 1.608024
# (Epoch 7 / 10) train acc: 0.539000; val_acc: 0.504000
# (Iteration 2701 / 3820) loss: 1.177615
# (Iteration 2801 / 3820) loss: 1.312268
# (Iteration 2901 / 3820) loss: 1.235100
# (Iteration 3001 / 3820) loss: 1.229919
# (Epoch 8 / 10) train acc: 0.548000; val_acc: 0.524000
# (Iteration 3101 / 3820) loss: 1.295976
# (Iteration 3201 / 3820) loss: 1.177947
# (Iteration 3301 / 3820) loss: 1.379700
# (Iteration 3401 / 3820) loss: 1.209844
# (Epoch 9 / 10) train acc: 0.513000; val_acc: 0.515000
# (Iteration 3501 / 3820) loss: 1.233285
# (Iteration 3601 / 3820) loss: 1.140756
# (Iteration 3701 / 3820) loss: 1.250728
# (Iteration 3801 / 3820) loss: 1.468444
# (Epoch 10 / 10) train acc: 0.579000; val_acc: 0.526000
# lr: 0.003, num_hiddens: 15, p: 0
# (Iteration 1 / 3820) loss: 2.307651
# (Epoch 0 / 10) train acc: 0.108000; val_acc: 0.105000
# (Iteration 101 / 3820) loss: 2.072916
# (Iteration 201 / 3820) loss: 1.844138
# (Iteration 301 / 3820) loss: 1.894658
# (Epoch 1 / 10) train acc: 0.290000; val_acc: 0.288000
# (Iteration 401 / 3820) loss: 1.808165
# (Iteration 501 / 3820) loss: 1.865529
# (Iteration 601 / 3820) loss: 1.909013
# (Iteration 701 / 3820) loss: 2.055585
# (Epoch 2 / 10) train acc: 0.316000; val_acc: 0.315000
# (Iteration 801 / 3820) loss: 1.793124
# (Iteration 901 / 3820) loss: 1.717775
# (Iteration 1001 / 3820) loss: 1.794075
# (Iteration 1101 / 3820) loss: 1.758659
# (Epoch 3 / 10) train acc: 0.352000; val_acc: 0.363000
# (Iteration 1201 / 3820) loss: 1.687109
# (Iteration 1301 / 3820) loss: 1.695514
# (Iteration 1401 / 3820) loss: 1.556202
# (Iteration 1501 / 3820) loss: 1.573531
# (Epoch 4 / 10) train acc: 0.373000; val_acc: 0.365000
# (Iteration 1601 / 3820) loss: 1.691745
# (Iteration 1701 / 3820) loss: 1.587293
# (Iteration 1801 / 3820) loss: 1.598449
# (Iteration 1901 / 3820) loss: 1.626708
# (Epoch 5 / 10) train acc: 0.427000; val_acc: 0.411000
# (Iteration 2001 / 3820) loss: 1.735016
# (Iteration 2101 / 3820) loss: 1.458458
# (Iteration 2201 / 3820) loss: 1.875484
# (Epoch 6 / 10) train acc: 0.482000; val_acc: 0.446000
# (Iteration 2301 / 3820) loss: 1.595095
# (Iteration 2401 / 3820) loss: 1.635669
# (Iteration 2501 / 3820) loss: 1.631404
# (Iteration 2601 / 3820) loss: 1.636610
# (Epoch 7 / 10) train acc: 0.488000; val_acc: 0.455000
# (Iteration 2701 / 3820) loss: 1.554678
# (Iteration 2801 / 3820) loss: 1.550493
# (Iteration 2901 / 3820) loss: 1.398151
# (Iteration 3001 / 3820) loss: 1.521694
# (Epoch 8 / 10) train acc: 0.457000; val_acc: 0.459000
# (Iteration 3101 / 3820) loss: 1.436567
# (Iteration 3201 / 3820) loss: 1.642540
# (Iteration 3301 / 3820) loss: 1.345133
# (Iteration 3401 / 3820) loss: 1.570980
# (Epoch 9 / 10) train acc: 0.502000; val_acc: 0.477000
# (Iteration 3501 / 3820) loss: 1.445816
# (Iteration 3601 / 3820) loss: 1.431169
# (Iteration 3701 / 3820) loss: 1.396058
# (Iteration 3801 / 3820) loss: 1.272534
# (Epoch 10 / 10) train acc: 0.528000; val_acc: 0.453000
# lr: 1e-05, num_hiddens: 15, p: 0
# (Iteration 1 / 3820) loss: 2.310831
# (Epoch 0 / 10) train acc: 0.120000; val_acc: 0.123000
# (Iteration 101 / 3820) loss: 2.298904
# (Iteration 201 / 3820) loss: 2.299177
# (Iteration 301 / 3820) loss: 2.287380
# (Epoch 1 / 10) train acc: 0.179000; val_acc: 0.137000
# (Iteration 401 / 3820) loss: 2.272735
# (Iteration 501 / 3820) loss: 2.254020
# (Iteration 601 / 3820) loss: 2.220960
# (Iteration 701 / 3820) loss: 2.201283
# (Epoch 2 / 10) train acc: 0.258000; val_acc: 0.205000
# (Iteration 801 / 3820) loss: 2.156872
# (Iteration 901 / 3820) loss: 2.138286
# (Iteration 1001 / 3820) loss: 2.065271
# (Iteration 1101 / 3820) loss: 2.061930
# (Epoch 3 / 10) train acc: 0.276000; val_acc: 0.259000
# (Iteration 1201 / 3820) loss: 2.079244
# (Iteration 1301 / 3820) loss: 2.045737
# (Iteration 1401 / 3820) loss: 1.970050
# (Iteration 1501 / 3820) loss: 2.037868
# (Epoch 4 / 10) train acc: 0.309000; val_acc: 0.311000
# (Iteration 1601 / 3820) loss: 2.070979
# (Iteration 1701 / 3820) loss: 1.983270
# ...
# (Iteration 1201 / 3820) loss: 2.290379
# (Iteration 1301 / 3820) loss: 2.305688
# (Iteration 1401 / 3820) loss: 2.304232
# (Iteration 1501 / 3820) loss: 2.318098
# (Epoch 4 / 10) train acc: 0.118000; val_acc: 0.119000
# (Iteration 1601 / 3820) loss: 2.312027
# (Iteration 1701 / 3820) loss: 2.308075
# (Iteration 1801 / 3820) loss: 2.303154
# (Iteration 1901 / 3820) loss: 2.308439
# (Epoch 5 / 10) train acc: 0.079000; val_acc: 0.105000
# (Iteration 2001 / 3820) loss: 2.306239
# (Iteration 2101 / 3820) loss: 2.323483
# (Iteration 2201 / 3820) loss: 2.301064
# (Epoch 6 / 10) train acc: 0.113000; val_acc: 0.102000
# (Iteration 2301 / 3820) loss: 2.295545
# (Iteration 2401 / 3820) loss: 2.303650
# (Iteration 2501 / 3820) loss: 2.319753
# (Iteration 2601 / 3820) loss: 2.309315
# (Epoch 7 / 10) train acc: 0.102000; val_acc: 0.079000
# (Iteration 2701 / 3820) loss: 2.315075
# (Iteration 2801 / 3820) loss: 2.297519
# (Iteration 2901 / 3820) loss: 2.306634
# (Iteration 3001 / 3820) loss: 2.309090
# (Epoch 8 / 10) train acc: 0.096000; val_acc: 0.098000
# (Iteration 3101 / 3820) loss: 2.315527
# (Iteration 3201 / 3820) loss: 2.309902
# (Iteration 3301 / 3820) loss: 2.303070
# (Iteration 3401 / 3820) loss: 2.297854
# (Epoch 9 / 10) train acc: 0.096000; val_acc: 0.107000
# (Iteration 3501 / 3820) loss: 2.307550
# (Iteration 3601 / 3820) loss: 2.310523
# (Iteration 3701 / 3820) loss: 2.290034
# (Iteration 3801 / 3820) loss: 2.317858
# (Epoch 10 / 10) train acc: 0.098000; val_acc: 0.087000
# lr: 0.3, num_hiddens: 10, p: 0.25
# (Iteration 1 / 3820) loss: 2.336378
# (Epoch 0 / 10) train acc: 0.103000; val_acc: 0.078000
# (Iteration 101 / 3820) loss: 2.325938
# (Iteration 201 / 3820) loss: 2.341388
# (Iteration 301 / 3820) loss: 2.299698
# (Epoch 1 / 10) train acc: 0.089000; val_acc: 0.098000
# (Iteration 401 / 3820) loss: 2.356193
# (Iteration 501 / 3820) loss: 2.314657
# (Iteration 601 / 3820) loss: 2.307427
# (Iteration 701 / 3820) loss: 2.311905
# (Epoch 2 / 10) train acc: 0.099000; val_acc: 0.107000
# (Iteration 801 / 3820) loss: 2.316476
# (Iteration 901 / 3820) loss: 2.363535
# (Iteration 1001 / 3820) loss: 2.352833
# (Iteration 1101 / 3820) loss: 2.337875
# (Epoch 3 / 10) train acc: 0.102000; val_acc: 0.113000
# (Iteration 1201 / 3820) loss: 2.383812
# (Iteration 1301 / 3820) loss: 2.301344
# (Iteration 1401 / 3820) loss: 2.315447
# (Iteration 1501 / 3820) loss: 2.312276
# (Epoch 4 / 10) train acc: 0.105000; val_acc: 0.079000
# (Iteration 1601 / 3820) loss: 2.324857
# (Iteration 1701 / 3820) loss: 2.316088
# (Iteration 1801 / 3820) loss: 2.305771
# (Iteration 1901 / 3820) loss: 2.318015
# (Epoch 5 / 10) train acc: 0.091000; val_acc: 0.112000
# (Iteration 2001 / 3820) loss: 2.304491
# (Iteration 2101 / 3820) loss: 2.308512
# (Iteration 2201 / 3820) loss: 2.295900
# (Epoch 6 / 10) train acc: 0.131000; val_acc: 0.113000
# (Iteration 2301 / 3820) loss: 2.342813
# (Iteration 2401 / 3820) loss: 2.300184
# (Iteration 2501 / 3820) loss: 2.313306
# (Iteration 2601 / 3820) loss: 2.310458
# (Epoch 7 / 10) train acc: 0.088000; val_acc: 0.087000
# (Iteration 2701 / 3820) loss: 2.322746
# (Iteration 2801 / 3820) loss: 2.316049
# (Iteration 2901 / 3820) loss: 2.303779
# (Iteration 3001 / 3820) loss: 2.327611
# (Epoch 8 / 10) train acc: 0.098000; val_acc: 0.107000
# (Iteration 3101 / 3820) loss: 2.337405
# (Iteration 3201 / 3820) loss: 2.349700
# (Iteration 3301 / 3820) loss: 2.313961
# (Iteration 3401 / 3820) loss: 2.309119
# (Epoch 9 / 10) train acc: 0.103000; val_acc: 0.113000
# (Iteration 3501 / 3820) loss: 2.305901
# (Iteration 3601 / 3820) loss: 2.304069
# (Iteration 3701 / 3820) loss: 2.295741
# (Iteration 3801 / 3820) loss: 2.321341
# (Epoch 10 / 10) train acc: 0.110000; val_acc: 0.119000
# lr: 0.001, num_hiddens: 10, p: 0.25
# (Iteration 1 / 3820) loss: 2.310963
# (Epoch 0 / 10) train acc: 0.102000; val_acc: 0.125000
# (Iteration 101 / 3820) loss: 2.336131
# (Iteration 201 / 3820) loss: 2.299327
# (Iteration 301 / 3820) loss: 2.286890
# (Epoch 1 / 10) train acc: 0.103000; val_acc: 0.102000
# (Iteration 401 / 3820) loss: 2.281235
# (Iteration 501 / 3820) loss: 2.163970
# (Iteration 601 / 3820) loss: 2.202673
# (Iteration 701 / 3820) loss: 2.126120
# (Epoch 2 / 10) train acc: 0.106000; val_acc: 0.098000
# (Iteration 801 / 3820) loss: 2.193823
# (Iteration 901 / 3820) loss: 2.141419
# (Iteration 1001 / 3820) loss: 2.191951
# (Iteration 1101 / 3820) loss: 2.113822
# (Epoch 3 / 10) train acc: 0.118000; val_acc: 0.102000
# (Iteration 1201 / 3820) loss: 2.194713
# (Iteration 1301 / 3820) loss: 2.224391
# (Iteration 1401 / 3820) loss: 2.104225
# (Iteration 1501 / 3820) loss: 2.157835
# (Epoch 4 / 10) train acc: 0.092000; val_acc: 0.102000
# (Iteration 1601 / 3820) loss: 2.057414
# (Iteration 1701 / 3820) loss: 2.093348
# (Iteration 1801 / 3820) loss: 2.025051
# (Iteration 1901 / 3820) loss: 2.189797
# (Epoch 5 / 10) train acc: 0.085000; val_acc: 0.102000
# (Iteration 2001 / 3820) loss: 2.213610
# (Iteration 2101 / 3820) loss: 2.099574
# (Iteration 2201 / 3820) loss: 2.093065
# (Epoch 6 / 10) train acc: 0.101000; val_acc: 0.098000
# (Iteration 2301 / 3820) loss: 2.104096
# (Iteration 2401 / 3820) loss: 2.138011
# (Iteration 2501 / 3820) loss: 2.094812
# (Iteration 2601 / 3820) loss: 2.068047
# (Epoch 7 / 10) train acc: 0.123000; val_acc: 0.102000
# (Iteration 2701 / 3820) loss: 2.075647
# (Iteration 2801 / 3820) loss: 2.130049
# (Iteration 2901 / 3820) loss: 2.025431
# (Iteration 3001 / 3820) loss: 2.139357
# (Epoch 8 / 10) train acc: 0.106000; val_acc: 0.102000
# (Iteration 3101 / 3820) loss: 2.019516
# (Iteration 3201 / 3820) loss: 2.041171
# (Iteration 3301 / 3820) loss: 2.109680
# (Iteration 3401 / 3820) loss: 2.042598
# (Epoch 9 / 10) train acc: 0.098000; val_acc: 0.102000
# (Iteration 3501 / 3820) loss: 2.096703
# (Iteration 3601 / 3820) loss: 2.133615
# (Iteration 3701 / 3820) loss: 2.059186
# (Iteration 3801 / 3820) loss: 2.051384
# (Epoch 10 / 10) train acc: 0.101000; val_acc: 0.102000
# lr: 0.003, num_hiddens: 10, p: 0.25
# (Iteration 1 / 3820) loss: 2.326469
# (Epoch 0 / 10) train acc: 0.081000; val_acc: 0.108000
# (Iteration 101 / 3820) loss: 2.302132
# (Iteration 201 / 3820) loss: 2.220767
# (Iteration 301 / 3820) loss: 2.241372
# (Epoch 1 / 10) train acc: 0.093000; val_acc: 0.104000
# (Iteration 401 / 3820) loss: 2.208974
# (Iteration 501 / 3820) loss: 2.226203
# (Iteration 601 / 3820) loss: 2.194622
# (Iteration 701 / 3820) loss: 2.184301
# (Epoch 2 / 10) train acc: 0.109000; val_acc: 0.098000
# (Iteration 801 / 3820) loss: 2.106942
# (Iteration 901 / 3820) loss: 2.148570
# (Iteration 1001 / 3820) loss: 2.149698
# (Iteration 1101 / 3820) loss: 2.157303
# (Epoch 3 / 10) train acc: 0.104000; val_acc: 0.078000
# (Iteration 1201 / 3820) loss: 2.151468
# (Iteration 1301 / 3820) loss: 1.963313
# (Iteration 1401 / 3820) loss: 2.006261
# (Iteration 1501 / 3820) loss: 2.185651
# (Epoch 4 / 10) train acc: 0.108000; val_acc: 0.102000
# (Iteration 1601 / 3820) loss: 2.115231
# (Iteration 1701 / 3820) loss: 2.164355
# (Iteration 1801 / 3820) loss: 2.122957
# (Iteration 1901 / 3820) loss: 2.115606
# (Epoch 5 / 10) train acc: 0.104000; val_acc: 0.103000
# (Iteration 2001 / 3820) loss: 2.081909
# (Iteration 2101 / 3820) loss: 2.120336
# (Iteration 2201 / 3820) loss: 2.088510
# (Epoch 6 / 10) train acc: 0.121000; val_acc: 0.131000
# (Iteration 2301 / 3820) loss: 2.139543
# (Iteration 2401 / 3820) loss: 2.090332
# (Iteration 2501 / 3820) loss: 2.110585
# (Iteration 2601 / 3820) loss: 2.061324
# (Epoch 7 / 10) train acc: 0.115000; val_acc: 0.133000
# (Iteration 2701 / 3820) loss: 2.020670
# (Iteration 2801 / 3820) loss: 2.085973
# (Iteration 2901 / 3820) loss: 2.068392
# (Iteration 3001 / 3820) loss: 2.112272
# (Epoch 8 / 10) train acc: 0.140000; val_acc: 0.141000
# (Iteration 3101 / 3820) loss: 2.101643
# (Iteration 3201 / 3820) loss: 2.083944
# (Iteration 3301 / 3820) loss: 2.060528
# (Iteration 3401 / 3820) loss: 2.095760
# (Epoch 9 / 10) train acc: 0.139000; val_acc: 0.135000
# (Iteration 3501 / 3820) loss: 2.120259
# (Iteration 3601 / 3820) loss: 2.073673
# (Iteration 3701 / 3820) loss: 2.074102
# (Iteration 3801 / 3820) loss: 2.114516
# (Epoch 10 / 10) train acc: 0.158000; val_acc: 0.141000
# lr: 1e-05, num_hiddens: 10, p: 0.25
# (Iteration 1 / 3820) loss: 2.304275
# (Epoch 0 / 10) train acc: 0.107000; val_acc: 0.073000
# (Iteration 101 / 3820) loss: 2.299343
# (Iteration 201 / 3820) loss: 2.324144
# (Iteration 301 / 3820) loss: 2.324174
# (Epoch 1 / 10) train acc: 0.112000; val_acc: 0.113000
# (Iteration 401 / 3820) loss: 2.324611
# (Iteration 501 / 3820) loss: 2.307022
# (Iteration 601 / 3820) loss: 2.305893
# (Iteration 701 / 3820) loss: 2.322091
# (Epoch 2 / 10) train acc: 0.096000; val_acc: 0.113000
# (Iteration 801 / 3820) loss: 2.323381
# (Iteration 901 / 3820) loss: 2.320571
# (Iteration 1001 / 3820) loss: 2.320527
# (Iteration 1101 / 3820) loss: 2.337106
# (Epoch 3 / 10) train acc: 0.111000; val_acc: 0.113000
# (Iteration 1201 / 3820) loss: 2.314567
# (Iteration 1301 / 3820) loss: 2.309249
# (Iteration 1401 / 3820) loss: 2.313186
# (Iteration 1501 / 3820) loss: 2.308354
# (Epoch 4 / 10) train acc: 0.076000; val_acc: 0.113000
# (Iteration 1601 / 3820) loss: 2.313182
# (Iteration 1701 / 3820) loss: 2.304426
# (Iteration 1801 / 3820) loss: 2.323677
# (Iteration 1901 / 3820) loss: 2.311108
# (Epoch 5 / 10) train acc: 0.099000; val_acc: 0.113000
# (Iteration 2001 / 3820) loss: 2.309822
# (Iteration 2101 / 3820) loss: 2.293212
# (Iteration 2201 / 3820) loss: 2.308305
# (Epoch 6 / 10) train acc: 0.084000; val_acc: 0.105000
# (Iteration 2301 / 3820) loss: 2.299047
# (Iteration 2401 / 3820) loss: 2.320517
# (Iteration 2501 / 3820) loss: 2.312723
# (Iteration 2601 / 3820) loss: 2.321298
# (Epoch 7 / 10) train acc: 0.105000; val_acc: 0.105000
# (Iteration 2701 / 3820) loss: 2.324878
# (Iteration 2801 / 3820) loss: 2.310143
# (Iteration 2901 / 3820) loss: 2.323452
# (Iteration 3001 / 3820) loss: 2.319931
# (Epoch 8 / 10) train acc: 0.073000; val_acc: 0.113000
# (Iteration 3101 / 3820) loss: 2.302363
# (Iteration 3201 / 3820) loss: 2.298298
# (Iteration 3301 / 3820) loss: 2.290626
# (Iteration 3401 / 3820) loss: 2.307675
# (Epoch 9 / 10) train acc: 0.110000; val_acc: 0.105000
# (Iteration 3501 / 3820) loss: 2.303055
# (Iteration 3601 / 3820) loss: 2.290643
# (Iteration 3701 / 3820) loss: 2.319340
# (Iteration 3801 / 3820) loss: 2.319902
# (Epoch 10 / 10) train acc: 0.114000; val_acc: 0.105000
# lr: 3e-05, num_hiddens: 10, p: 0.25
# (Iteration 1 / 3820) loss: 2.331188
# (Epoch 0 / 10) train acc: 0.108000; val_acc: 0.109000
# (Iteration 101 / 3820) loss: 2.299798
# (Iteration 201 / 3820) loss: 2.301113
# (Iteration 301 / 3820) loss: 2.307971
# (Epoch 1 / 10) train acc: 0.125000; val_acc: 0.079000
# (Iteration 401 / 3820) loss: 2.301625
# (Iteration 501 / 3820) loss: 2.296758
# (Iteration 601 / 3820) loss: 2.304755
# (Iteration 701 / 3820) loss: 2.323476
# (Epoch 2 / 10) train acc: 0.101000; val_acc: 0.079000
# (Iteration 801 / 3820) loss: 2.313270
# (Iteration 901 / 3820) loss: 2.295562
# (Iteration 1001 / 3820) loss: 2.286705
# (Iteration 1101 / 3820) loss: 2.293757
# (Epoch 3 / 10) train acc: 0.089000; val_acc: 0.102000
# (Iteration 1201 / 3820) loss: 2.303985
# (Iteration 1301 / 3820) loss: 2.282980
# (Iteration 1401 / 3820) loss: 2.264243
# (Iteration 1501 / 3820) loss: 2.240089
# (Epoch 4 / 10) train acc: 0.101000; val_acc: 0.102000
# (Iteration 1601 / 3820) loss: 2.292578
# (Iteration 1701 / 3820) loss: 2.233928
# (Iteration 1801 / 3820) loss: 2.226985
# (Iteration 1901 / 3820) loss: 2.247132
# (Epoch 5 / 10) train acc: 0.096000; val_acc: 0.102000
# (Iteration 2001 / 3820) loss: 2.235362
# (Iteration 2101 / 3820) loss: 2.250861
# (Iteration 2201 / 3820) loss: 2.221783
# (Epoch 6 / 10) train acc: 0.086000; val_acc: 0.102000
# (Iteration 2301 / 3820) loss: 2.182593
# (Iteration 2401 / 3820) loss: 2.199712
# (Iteration 2501 / 3820) loss: 2.207590
# (Iteration 2601 / 3820) loss: 2.204853
# (Epoch 7 / 10) train acc: 0.098000; val_acc: 0.102000
# (Iteration 2701 / 3820) loss: 2.179782
# (Iteration 2801 / 3820) loss: 2.188016
# (Iteration 2901 / 3820) loss: 2.247330
# (Iteration 3001 / 3820) loss: 2.198728
# (Epoch 8 / 10) train acc: 0.095000; val_acc: 0.102000
# (Iteration 3101 / 3820) loss: 2.215739
# (Iteration 3201 / 3820) loss: 2.165117
# (Iteration 3301 / 3820) loss: 2.189229
# (Iteration 3401 / 3820) loss: 2.167803
# (Epoch 9 / 10) train acc: 0.098000; val_acc: 0.102000
# (Iteration 3501 / 3820) loss: 2.184484
# (Iteration 3601 / 3820) loss: 2.169836
# (Iteration 3701 / 3820) loss: 2.205963
# (Iteration 3801 / 3820) loss: 2.170867
# (Epoch 10 / 10) train acc: 0.085000; val_acc: 0.102000
# lr: 0.1, num_hiddens: 15, p: 0.25
# (Iteration 1 / 3820) loss: 2.317254
# (Epoch 0 / 10) train acc: 0.085000; val_acc: 0.079000
# (Iteration 101 / 3820) loss: 2.303519
# (Iteration 201 / 3820) loss: 2.304912
# (Iteration 301 / 3820) loss: 2.360551
# (Epoch 1 / 10) train acc: 0.095000; val_acc: 0.113000
# (Iteration 401 / 3820) loss: 2.312219
# (Iteration 501 / 3820) loss: 2.310939
# (Iteration 601 / 3820) loss: 2.323591
# (Iteration 701 / 3820) loss: 2.316748
# (Epoch 2 / 10) train acc: 0.119000; val_acc: 0.102000
# (Iteration 801 / 3820) loss: 2.308252
# (Iteration 901 / 3820) loss: 2.291343
# (Iteration 1001 / 3820) loss: 2.314011
# (Iteration 1101 / 3820) loss: 2.313127
# (Epoch 3 / 10) train acc: 0.107000; val_acc: 0.107000
# (Iteration 1201 / 3820) loss: 2.331729
# (Iteration 1301 / 3820) loss: 2.309137
# (Iteration 1401 / 3820) loss: 2.306867
# (Iteration 1501 / 3820) loss: 2.308162
# (Epoch 4 / 10) train acc: 0.094000; val_acc: 0.107000
# (Iteration 1601 / 3820) loss: 2.302649
# (Iteration 1701 / 3820) loss: 2.306348
# (Iteration 1801 / 3820) loss: 2.308018
# (Iteration 1901 / 3820) loss: 2.306114
# (Epoch 5 / 10) train acc: 0.098000; val_acc: 0.119000
# (Iteration 2001 / 3820) loss: 2.319239
# (Iteration 2101 / 3820) loss: 2.336937
# (Iteration 2201 / 3820) loss: 2.323440
# (Epoch 6 / 10) train acc: 0.115000; val_acc: 0.087000
# (Iteration 2301 / 3820) loss: 2.300697
# (Iteration 2401 / 3820) loss: 2.313058
# (Iteration 2501 / 3820) loss: 2.291818
# (Iteration 2601 / 3820) loss: 2.306949
# (Epoch 7 / 10) train acc: 0.100000; val_acc: 0.112000
# (Iteration 2701 / 3820) loss: 2.297075
# (Iteration 2801 / 3820) loss: 2.310251
# (Iteration 2901 / 3820) loss: 2.299083
# (Iteration 3001 / 3820) loss: 2.320978
# (Epoch 8 / 10) train acc: 0.095000; val_acc: 0.079000
# (Iteration 3101 / 3820) loss: 2.295698
# (Iteration 3201 / 3820) loss: 2.279746
# (Iteration 3301 / 3820) loss: 2.307022
# (Iteration 3401 / 3820) loss: 2.305576
# (Epoch 9 / 10) train acc: 0.112000; val_acc: 0.119000
# (Iteration 3501 / 3820) loss: 2.302551
# (Iteration 3601 / 3820) loss: 2.301971
# (Iteration 3701 / 3820) loss: 2.305208
# (Iteration 3801 / 3820) loss: 2.317192
# (Epoch 10 / 10) train acc: 0.098000; val_acc: 0.112000
# lr: 0.3, num_hiddens: 15, p: 0.25
# (Iteration 1 / 3820) loss: 2.309936
# (Epoch 0 / 10) train acc: 0.102000; val_acc: 0.113000
# (Iteration 101 / 3820) loss: 2.322255
# (Iteration 201 / 3820) loss: 2.300141
# (Iteration 301 / 3820) loss: 2.309384
# (Epoch 1 / 10) train acc: 0.088000; val_acc: 0.105000
# (Iteration 401 / 3820) loss: 2.314976
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-5d3f8cb0d989> in <module>
#      29                                       dtype=np.float64)
#      30             solver = Solver(model, data, **conf)
# ---> 31             solver.train()
#      32             curr_val = max(solver.val_acc_history)
#      33             if curr_val > best_val:
#
# ~/cs231n/assignment2/cs231n/solver.py in train(self)
#     265         for t in range(num_iterations):
#     266
# --> 267             self._step()
#     268
#     269             # Maybe print training loss
#
# ~/cs231n/assignment2/cs231n/solver.py in _step(self)
#     187             dw = grads[p]
#     188             config = self.optim_configs[p]
# --> 189             next_w, next_config = self.update_rule(w, dw, config)
#     190             self.model.params[p] = next_w
#     191             self.optim_configs[p] = next_config
#
# ~/cs231n/assignment2/cs231n/optim.py in adam(x, dx, config)
#     141     config['t'] += 1
#     142     config['m'] = config['beta1']*config['m'] + (1-config['beta1'])*dx
# --> 143     config['v'] = config['beta2'] * config['v'] + (1 - config['beta2']) * (dx ** 2)
#     144     mt = config['m'] / (1 - (config['beta1']**config['t']))
#     145     vt = config['v'] / (1 - (config['beta2']**config['t']))
#
# KeyboardInterrupt:

# %% [markdown]
# # Test you model
# Run your best model on the validation and test sets. You should achieve above 50% accuracy on the validation set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Validation set accuracy:  0.543
# Test set accuracy:  0.543
